# %% [markdown]
# # Analyzing the Impact of Weather on Air Quality in New York City
# Abstract
# This project focuses on examining the trends in weather and Air Quality Index (AQI) data for Manhattan, New York throughout 2021. Using time series analysis and exploratory data analysis (EDA), we investigated how different weather conditions affect AQI, providing insights into the environmental dynamics of an urban setting.
#
# Introduction
# The motivation behind this study stems from the increasing concern over environmental quality and its impact on public health. As New York City is a bustling metropolis with significant industrial and vehicular emissions, understanding the interplay between weather conditions and air quality is crucial for public health policy and urban planning.
#
# Research Questions
# What are the trends in weather and air quality in New York City for the year 2021?
# Is there a correlation between weather conditions and air quality in New York City? If yes, how do specific weather variables affect AQI?
# Data Sources
# Weather Data: Retrieved from the National Oceanic and Atmospheric Administration (NOAA) via National Centers For Environmental Information.
# Air Quality Data: Sourced from NYC Open Data which provides an API for accessing daily AQI readings.
# Research Methodology
# Data Collection
# Weather Data: Includes daily measurements of temperature, humidity, wind speed, and air pressure.
# AQI Data: Consists of daily air quality measurements categorized into different levels from Good to Hazardous.
# Data Preparation
# Data cleaning included handling missing values, correcting data types, and normalization of date formats.
# Data transformation involved aggregating daily data to monthly averages to observe broader trends.
# Exploratory Data Analysis
# Visual analysis using time series plots to identify trends and seasonal patterns in weather and AQI.
# Box plots to examine the distribution and identify outliers in the data sets.
# Statistical Analysis
# Correlation analysis using Pearson’s correlation coefficient to explore the relationships between different weather variables and AQI.
# Regression analysis to model the impact of weather conditions on AQI.
# Data Visualization
# Interactive visualizations using libraries like Cufflinks and Plotly to create dynamic charts that allow for a deeper exploration of the data.
# Heatmaps to visualize the correlation matrix between weather variables and AQI.
# Findings and Discussion
# Trends: The study revealed that temperature and humidity have significant seasonal fluctuations which correspond with changes in AQI levels. Higher temperatures in summer correlate with higher AQI levels, indicating poor air quality.
# Correlation Analysis:
# Temperature and AQI showed a moderate positive correlation, suggesting that warmer days tend to have poorer air quality.
# Wind Speed and AQI exhibited a negative correlation, indicating that increased wind speeds are associated with better air quality, likely due to the dispersion of pollutants.
# Humidity and AQI also showed a positive correlation, suggesting that higher humidity levels could exacerbate air quality conditions.
# Statistical Modeling: Regression models highlighted that while weather conditions significantly impact AQI, they account for only a part of the variability. Other factors such as traffic emissions and industrial activities also play crucial roles.
# By Vijayasuriya Suresh

# %% [markdown]
# # Abstract

# %% [markdown]
# In this project, we analyzed trends in weather and AQI data for Manhattan, New York in 2021 by plotting time series through exploratory data analysis and investigated the impact of weather on AQI in the region through correlation analysis.
# - New York City(NYC) has four distinct seasons, with cold winters and hot summers. The maximum amount of rainfall occurs in summer. In 2021, the wind speed in NYC is relatively uniform with no significant trend. Because of the maritime climate, there is no significant trend in humidity in NYC over the course of the year. There is no significant trend in pressure. There is also no clear trend in NYC AQI, but there are several peaks in the summer and winter months.
# - Through correlation analysis, we know that temperature, humidity and wind speed have the greatest influence on AQI. The greater the temperature and the moderate, the greater the AQI; the greater the wind speed, the smaller the AQI.

# %% [markdown]
# # Introduction

# %% [markdown]
# With the continuous improvement of people's living standards, people pay more and more attention to the quality of life. They pay more attention to the surrounding air quality, weather, and climate change. Human health is affected by the weather. When the surrounding weather factors, such as temperature, humidity, air pressure, wind, and so on, change significantly, it will affect some people's health. At the same time, the air quality  has been closely related to people's lives. The relationship between urban air quality and weather conditions is related, and meteorological conditions will affect the quality of air quality when there is no significant change in emissions from pollution sources. (Reference: https://www.preventionweb.net/news/world-meteorological-day-2009-weather-climate-and-air-we-breathe)
#
# New York City has a large population of 8,804,190. And this number is growing. Since the 2010 census, the number has increased by 629,057 by April 1, 2020. (Reference: https://www1.nyc.gov/site/planning/planning-level/nyc-population/nyc-population.page) The lives and health of so many residents in New York City are affected by local weather and air quality. Therefore, it is undoubtedly important to analyze the weather and air quality in New York City and find out their characteristics and correlation.
#
# ## Research Questions
# - What was the trend of weather and air quality in New York City in the past?
# - Is there a clear correlation between weather and air quality in New York City? If so, how does the weather affect air quality? If it does not exist, what causes this result?
#
#  We will analyze the weather and air quality of New York City through time series, study their change trend, and analyze the correlation between the two groups of data.
#
# ## Data Source
# -  New York City weather data will be obtained from the National Centers For Environmental Information website of the National Oceanic and Atmospheric Administration. The website provides data download in CSV format. Link: https://www.ncdc.noaa.gov/cdo-web/datatools/lcd
# -  The air quality data of New York City will be obtained from the NYC open data website. The website provides APIs. Link: https://data.cityofnewyork.us/Environment/Air-Quality/c3uy-2p5r

# %% [markdown]
# # Research Approach
# - Get weather and air quality index data by csv file import and AQI, respectively. Upload the csv file to github for easy fetching. Convert all date data to datetime format for easy grouping and aggregation of dates. Converts continuous numeric variables to float or integer types.
# - EDA of both datasets to find information such as data outliers and trends. Check for missing values and then view the distribution statistics. Plot box plots for each numeric variable to view outliers. Plot a time series plot for each attribute to see trends.
# - Create feature works for AQI data and create categorical variables for differentiating AQI levels. Count the number of different AQI levels for each month in groups. Using Cufflinks, plot an interactive bar graph of those counts.
# - Construct prediction models for AQI data using sklearn.
# - Using Pearson's correlation coefficient to analyze the correlation between weather data and AQI.

# %% [markdown]
# # Exploratory Data Analysis -- weather
#
# ### Import weather data from csv file.

# %%
# Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
weather = pd.read_csv('https://raw.githubusercontent.com/Jane-426/DAV_5400/main/3170037.csv')
weather = pd.DataFrame(weather, columns=['DATE', 'DailyAverageDewPointTemperature', 'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity', 
                        'DailyAverageSeaLevelPressure', 'DailyAverageStationPressure', 'DailyAverageWetBulbTemperature', 
                        'DailyAverageWindSpeed','DailyPrecipitation', 'DailySnowfall', 'DailySustainedWindDirection', 'DailySustainedWindSpeed'])
# Delete null rows
weather = weather.dropna().reset_index(drop=True)
weather.head()
# Out:
# /var/folders/n8/mf8_4h7112b4xy3jmk_zlmtm0000gn/T/ipykernel_1069/1955919295.py:7: DtypeWarning: Columns (35,43,44,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   weather = pd.read_csv('https://raw.githubusercontent.com/Jane-426/DAV_5400/main/3170037.csv')
#                   DATE  DailyAverageDewPointTemperature  \
# 0  2021-01-01T23:59:00                             27.0
# 1  2021-01-02T23:59:00                             34.0
# 2  2021-01-03T23:59:00                             31.0
# 3  2021-01-04T23:59:00                             31.0
# 4  2021-01-05T23:59:00                             29.0
#
#    DailyAverageDryBulbTemperature  DailyAverageRelativeHumidity  \
# 0                            37.0                          69.0
# 1                            44.0                          74.0
# 2                            36.0                          83.0
# 3                            39.0                          77.0
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DATE                             343 non-null    object
#  1   DailyAverageDewPointTemperature  343 non-null    float64
#  2   DailyAverageDryBulbTemperature   343 non-null    float64
#  3   DailyAverageRelativeHumidity     343 non-null    float64
#  4   DailyAverageSeaLevelPressure     343 non-null    float64
#  5   DailyAverageStationPressure      343 non-null    float64
#  6   DailyAverageWetBulbTemperature   343 non-null    float64
#  7   DailyAverageWindSpeed            343 non-null    float64
#  8   DailyPrecipitation               343 non-null    object
#  9   DailySnowfall                    343 non-null    object
#  10  DailySustainedWindDirection      343 non-null    float64
#  11  DailySustainedWindSpeed          343 non-null    float64
# ...

# %% [markdown]
# ### Convert data types

# %%
# Convert DATE column to a datetime
weather.DATE=pd.to_datetime(weather.DATE)
weather['DATE']= weather['DATE'].dt.date
weather['DATE'] = pd.to_datetime(weather['DATE'])

# %%
# View the unique value of the object variable
weather.DailyPrecipitation.unique()
# Out:
# array(['0.62', '0.05', '0.22', '0.02', '0.00', '0.38', '0.78', '0.10',
#        '0.12', '1.85', '0.13', '0.01', '0.07', '0.39', 'T', '0.82',
#        '0.45', '0.14', '0.52', '0.16', '0.60', '1.27', '0.19', '0.76',
#        '0.35', '0.03', '0.42', '0.49', '0.06', '0.83', '0.04', '0.11',
#        '0.59', '0.58', '0.23', '0.31', '0.47', '1.22', '0.46', '0.89',
#        '0.24', '0.65', '0.90', '0.67', '0.34', '0.55', '2.27', '2.06',
#        '0.27', '1.42', '0.21', '0.18', '0.20', '4.45', '2.67', '1.07',
#        '7.13', '1.37', '0.66', '0.25', '3.30', '0.41', '0.57', '0.48',
#        '0.33', '0.09', '0.17'], dtype=object)

# %%
weather.DailySnowfall.unique()
# Out:
# array(['0.0', 'T', '0.1', '2.0', '14.8', '0.4', '0.2', '4.5', '1.3',
#        '3.2', '1.2'], dtype=object)

# %%
# T stands for Track, which means that the amount of measured value is too small to be measured, so we consider T as 0.
weather['DailyPrecipitation'] = weather['DailyPrecipitation'].replace(['T'], '0')
weather['DailySnowfall'] = weather['DailySnowfall'].replace(['T'], '0')
# View the unique value of all object variables
pd.concat([weather['DailyPrecipitation'], weather['DailySnowfall']]).unique()
# Out:
# array(['0.62', '0.05', '0.22', '0.02', '0.00', '0.38', '0.78', '0.10',
#        '0.12', '1.85', '0.13', '0.01', '0.07', '0.39', '0', '0.82',
#        '0.45', '0.14', '0.52', '0.16', '0.60', '1.27', '0.19', '0.76',
#        '0.35', '0.03', '0.42', '0.49', '0.06', '0.83', '0.04', '0.11',
#        '0.59', '0.58', '0.23', '0.31', '0.47', '1.22', '0.46', '0.89',
#        '0.24', '0.65', '0.90', '0.67', '0.34', '0.55', '2.27', '2.06',
#        '0.27', '1.42', '0.21', '0.18', '0.20', '4.45', '2.67', '1.07',
#        '7.13', '1.37', '0.66', '0.25', '3.30', '0.41', '0.57', '0.48',
#        '0.33', '0.09', '0.17', '0.0', '0.1', '2.0', '14.8', '0.4', '0.2',
#        '4.5', '1.3', '3.2', '1.2'], dtype=object)

# %%
# Covert data type from object to float
weather["DailyPrecipitation"] = weather.DailyPrecipitation.astype(float)
weather["DailySnowfall"] = weather.DailyPrecipitation.astype(float)
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DATE                             343 non-null    datetime64[ns]
#  1   DailyAverageDewPointTemperature  343 non-null    float64
#  2   DailyAverageDryBulbTemperature   343 non-null    float64
#  3   DailyAverageRelativeHumidity     343 non-null    float64
#  4   DailyAverageSeaLevelPressure     343 non-null    float64
#  5   DailyAverageStationPressure      343 non-null    float64
#  6   DailyAverageWetBulbTemperature   343 non-null    float64
#  7   DailyAverageWindSpeed            343 non-null    float64
#  8   DailyPrecipitation               343 non-null    float64
#  9   DailySnowfall                    343 non-null    float64
#  10  DailySustainedWindDirection      343 non-null    float64
# ...

# %% [markdown]
# ### Check for missing values

# %%
# Checking for total null values.
weather.isna().sum()
# Out:
# DATE                               0
# DailyAverageDewPointTemperature    0
# DailyAverageDryBulbTemperature     0
# DailyAverageRelativeHumidity       0
# DailyAverageSeaLevelPressure       0
# DailyAverageStationPressure        0
# DailyAverageWetBulbTemperature     0
# DailyAverageWindSpeed              0
# DailyPrecipitation                 0
# DailySnowfall                      0
# DailySustainedWindDirection        0
# DailySustainedWindSpeed            0
# dtype: int64

# %% [markdown]
# There's no missing values.

# %% [markdown]
# ### Statistical distribution

# %%
# Show some simple distribution statistics.
weather.describe()
# Out:
#        DailyAverageDewPointTemperature  DailyAverageDryBulbTemperature  \
# count                       343.000000                      343.000000
# mean                         41.842566                       56.688047
# std                          18.950497                       16.692929
# min                          -3.000000                       20.000000
# 25%                          26.000000                       43.000000
# 50%                          42.000000                       57.000000
# 75%                          59.000000                       71.000000
# max                          72.000000                       87.000000
#
#        DailyAverageRelativeHumidity  DailyAverageSeaLevelPressure  \
# count                    343.000000                    343.000000
# mean                      61.446064                     30.014927
# std                       16.112430                      0.200193
# ...

# %% [markdown]
# The maximum values of DailyPrecipitation and DailySnowfall are much larger than the upper quartile, indicating possible outliers.

# %% [markdown]
# ### BoxPlot and LinePlot

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageDewPointTemperature', data = weather)
# give the plot a title
plt.title('Boxplot of Average Dew Point Temperature')
# name y axis
plt.ylabel('Average Dew Point Temperature')
plt.show();

# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageDewPointTemperature', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Dew Point Temperature')
# give the plot a title
plt.title('Line plot of Daily Average Dew Point Temperature')
plt.show();

# %% [markdown]
# There are no outliers and the time series plot shows that Dew Point temperature reaches a minimum around March and then slowly increases until it reaches a maximum in August and then slowly decreases during the year.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageDryBulbTemperature', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Average Dry Bulb Temperature')
# name y axis
plt.ylabel('Daily Average Dry Bulb Temperature')
plt.show();

# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageDryBulbTemperature', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Dry Bulb Temperature')
# give the plot a title
plt.title('Line plot of Daily Average Dry Bulb Temperature')
plt.show();

# %% [markdown]
# There are no outliers and the time series plot shows that Dry Bulb temperature reaches a minimum around February and then slowly increases until it reaches a maximum in July and then slowly decreases during the year.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageRelativeHumidity', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Average Relative Humidity')
# name y axis
plt.ylabel('Daily Average Relative Humidity')
plt.show();

# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageRelativeHumidity', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Relative Humidity')
# give the plot a title
plt.title('Line plot of Daily Average Relative Humidity')
plt.show();

# %% [markdown]
# There are no outliers, and the time series plot shows that there are increasing fluctuations in the correlated humidity around March and decreasing fluctuations around September.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageSeaLevelPressure', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Average Sea Level Pressure')
# name y axis
plt.ylabel('Daily Average Sea Level Pressure')
plt.show();

# %% [markdown]
# There are only a few outliers, and we can remove them.

# %%
# Detecting the outliers using IQR and removing them.
# IQR
Q1 = np.percentile(weather['DailyAverageSeaLevelPressure'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(weather['DailyAverageSeaLevelPressure'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
# Upper bound
upper = np.where(weather['DailyAverageSeaLevelPressure'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(weather['DailyAverageSeaLevelPressure'] <= (Q1-1.5*IQR))
# Removing the Outliers
weather.drop(upper[0], inplace = True)
weather.drop(lower[0], inplace = True)

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageSeaLevelPressure', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Sea Level Pressure')
# give the plot a title
plt.title('Line plot of Daily Average Sea Level Pressure')
plt.show();

# %% [markdown]
# Although the box plot shows outliers, the data set as a whole fluctuates above and below 30, so the Sea Level Pressure can be considered as a small smooth fluctuation.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageStationPressure', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Average Station Pressure')
# name y axis
plt.ylabel('Daily Average Station Pressure')
plt.show();

# %% [markdown]
# Since the percentage of outliers is very low, we choose to remove them.

# %%
# Detecting the outliers using IQR and removing them.
# IQR
Q1 = np.percentile(weather['DailyAverageStationPressure'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(weather['DailyAverageStationPressure'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
# Upper bound
upper = np.where(weather['DailyAverageStationPressure'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(weather['DailyAverageStationPressure'] <= (Q1-1.5*IQR))
# Removing the Outliers
weather.drop(upper[0], inplace = True)
weather.drop(lower[0], inplace = True)

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageStationPressure', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Station Pressure')
# give the plot a title
plt.title('Line plot of Daily Average Station Pressure')
plt.show();

# %% [markdown]
# Although the box plot shows outliers, the data set as a whole fluctuates above and below 30, so the Station Pressure can be considered as a small smooth fluctuation.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageWetBulbTemperature', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Average Wet Bulb Temperature')
# name y axis
plt.ylabel('Daily Average Wet Bulb Temperature')
plt.show();

# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageWetBulbTemperature', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Wet Bulb Temperature')
# give the plot a title
plt.title('Line plot of Daily Average Wet Bulb Temperature')
plt.show();

# %% [markdown]
# There are no outliers, and the time series plot shows that the dry bulb temperature reaches a minimum around February, then rises slowly until it reaches a maximum in July, and then decreases slowly throughout the year.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyAverageWindSpeed', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Average Wind Speed')
# name y axis
plt.ylabel('Daily Average Wind Speed')
plt.show();

# %% [markdown]
# Since the percentage of outliers is very low, we choose to remove them.

# %%
# Detecting the outliers using IQR and removing them.
# IQR
Q1 = np.percentile(weather['DailyAverageWindSpeed'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(weather['DailyAverageWindSpeed'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
# Upper bound
upper = np.where(weather['DailyAverageWindSpeed'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(weather['DailyAverageWindSpeed'] <= (Q1-1.5*IQR))
# Removing the Outliers
weather.drop(upper[0], inplace = True)
weather.drop(lower[0], inplace = True)

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyAverageWindSpeed', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Average Wind Speed')
# give the plot a title
plt.title('Line plot of Daily Average Wind Speed')
plt.show();

# %% [markdown]
# The time series plot shows that Average Wind Speed is larger in winter and smaller in summer.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailyPrecipitation', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Precipitation')
# name y axis
plt.ylabel('Daily Precipitation')
plt.show();

# %%
# Position of the Outlier
print(np.where(weather['DailyPrecipitation']>0.2))
# Out:
# (array([  0,   2,  14,  32,  41,  43,  47,  52,  53,  69,  75,  79,  82,
#         90,  91,  94, 103, 110, 111, 112, 116, 134, 135, 136, 140, 141,
#        145, 151, 159, 167, 168, 169, 170, 173, 175, 176, 177, 179, 184,
#        192, 193, 196, 206, 208, 219, 220, 221, 225, 229, 242, 243, 257,
#        266, 269, 270, 283, 284, 306]),)

# %% [markdown]
# Since there are many outliers, we cannot delete them. And from the graph, we can see that the rest of the values are about 0 except for the exceptions, so this should be the real value due to the abnormal weather.

# %%
#  Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailyPrecipitation', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Precipitation')
# give the plot a title
plt.title('Line plot of Daily Precipitation')
plt.show();

# %% [markdown]
# As can be seen from the time series plot, Precipitation values are usually close to zero but produce several unusually high values around September.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailySnowfall', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Snowfall')
# name y axis
plt.ylabel('Daily Snowfall')
plt.show();

# %%
# Position of the Outlier
print(np.where(weather['DailyPrecipitation']>0.2))
# Out:
# (array([  0,   2,  14,  32,  41,  43,  47,  52,  53,  69,  75,  79,  82,
#         90,  91,  94, 103, 110, 111, 112, 116, 134, 135, 136, 140, 141,
#        145, 151, 159, 167, 168, 169, 170, 173, 175, 176, 177, 179, 184,
#        192, 193, 196, 206, 208, 219, 220, 221, 225, 229, 242, 243, 257,
#        266, 269, 270, 283, 284, 306]),)

# %% [markdown]
# Since there are many outliers, we cannot delete them. And from the graph, we can see that the rest of the values are about 0 except for the exceptions, so this should be the real value due to the abnormal weather.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailySnowfall', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Snowfall')
# give the plot a title
plt.title('Line plot of Daily Snowfall')
plt.show();

# %% [markdown]
# As can be seen from the time series plot, Snowfall values are usually close to zero but produce several unusually high values around September.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailySustainedWindDirection', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Sustained Wind Direction')
# name y axis
plt.ylabel('Daily Sustained Wind Direction')
plt.show();

# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailySustainedWindDirection', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Sustained Wind Direction')
# give the plot a title
plt.title('Line plot of Daily Sustained Wind Direction')
plt.show();

# %% [markdown]
# There are no outliers. Based on the time series plot it can be seen that the sustained wind direction fluctuates uniformly and substantially throughout the year.

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for weather variables
sns.boxplot(y = 'DailySustainedWindSpeed', data = weather)
# give the plot a title
plt.title('Boxplot of Daily Sustained Wind Speed')
# name y axis
plt.ylabel('Daily Sustained Wind Speed')
plt.show();

# %% [markdown]
# Since the percentage of outliers is very low, we choose to remove them.

# %%
# Detecting the outliers using IQR and removing them.
# IQR
Q1 = np.percentile(weather['DailySustainedWindSpeed'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(weather['DailySustainedWindSpeed'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
# Upper bound
upper = np.where(weather['DailySustainedWindSpeed'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(weather['DailySustainedWindSpeed'] <= (Q1-1.5*IQR))
# Removing the Outliers
weather.drop(upper[0], inplace = True)
weather.drop(lower[0], inplace = True)

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot 
# .dt.date will remove the time component for x axis
sns.lineplot(ax = ax, x=weather.DATE.dt.date, y='DailySustainedWindSpeed', data=weather)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Daily Sustained Wind Speed')
# give the plot a title
plt.title('Line plot of Daily Sustained Wind Speed')
plt.show();

# %% [markdown]
# Based on the time series, we can see that Sustained Wind Speed has a slow upward trend until April, reaches a high value in April, and then slowly decreases until it reaches a low value in October and slowly increases again.

# %%
weather.corr()
# Out:
#                                  DailyAverageDewPointTemperature  \
# DailyAverageDewPointTemperature                         1.000000
# DailyAverageDryBulbTemperature                          0.922081
# DailyAverageRelativeHumidity                            0.619828
# DailyAverageSeaLevelPressure                           -0.254011
# DailyAverageStationPressure                            -0.225681
# DailyAverageWetBulbTemperature                          0.977831
# DailyAverageWindSpeed                                  -0.524704
# DailyPrecipitation                                      0.241430
# DailySnowfall                                           0.241430
# DailySustainedWindDirection                            -0.207056
# DailySustainedWindSpeed                                -0.383821
#
#                                  DailyAverageDryBulbTemperature  \
# DailyAverageDewPointTemperature                        0.922081
# ...

# %% [markdown]
# The relationship between the weather-related data can be seen in the table. There are strong positive correlations between the respective correlated variables of temperature, humidity, and wind speed. snowfall and Precipitation correlations are extremely strong.

# %% [markdown]
# # Exploratory Data Analysis -- AQI

# %% [markdown]
# An air quality index (AQI) is used by government agencies to communicate to the public how polluted the air currently is or how polluted it is forecast to become. AQI information is obtained by averaging readings from an air quality sensor, which can increase due to vehicle traffic, forest fires, or anything that can increase air pollution. Pollutants tested include ozone, nitrogen dioxide, sulphur dioxide, among others.
#
# Public health risks increase as the AQI rises, especially affecting children, the elderly, and individuals with respiratory or cardiovascular issues. During these times, governmental bodies generally encourage people to reduce physical activity outdoors, or even avoid going out altogether. The use of face masks such as cloth masks may also be recommended.
#
# The United States Environmental Protection Agency (EPA) has developed an Air Quality Index that is used to report air quality. This AQI is divided into six categories indicating increasing levels of health concern. An AQI value over 300 represents hazardous air quality and below 50 the air quality is good.

# %% [markdown]
# ### Import air quality data from web API

# %%
# Import the required libraries
import pandas as pd
import requests
import json
from pandas.io.json import json_normalize

# Returns an array of the Air Quality
air_quality = requests.get('https://aqs.epa.gov/data/api/dailyData/byCounty?email=mwang3@mail.yu.edu&key=indigoswift45&param=88101&bdate=20210101&edate=20211231&state=36&county=061')
# API status code
print(air_quality.status_code)

import requests
from pprint import pprint

def airquality(query):
    res=requests.get('https://aqs.epa.gov/data/api/dailyData/byCounty?email=mwang3@mail.yu.edu&key=indigoswift45&param=88101&bdate=20210101&edate=20211231&state=36&county=061');
    return res.json();

# Retrieved data of the Air Quality
air_quality = airquality(air_quality)
air_quality = air_quality['Data']
air_quality
# Out:
# 200
# [{'state_code': '36',
#   'county_code': '061',
#   'site_number': '0079',
#   'parameter_code': '88101',
#   'poc': 1,
#   'latitude': 40.7997,
#   'longitude': -73.93432,
#   'datum': 'WGS84',
#   'parameter': 'PM2.5 - Local Conditions',
#   'sample_duration_code': '7',
#   'sample_duration': '24 HOUR',
#   'pollutant_standard': 'PM25 Annual 1997',
#   'date_local': '2021-12-30',
#   'units_of_measure': 'Micrograms/cubic meter (LC)',
#   'event_type': 'No Events',
#   'observation_count': 1,
#   'observation_percent': 100.0,
#   'validity_indicator': 'Y',
#   'arithmetic_mean': 18.6,
#   'first_max_value': 18.6,
#   'first_max_hour': 0,
#   'aqi': 65,
#   'method_code': '145',
#   'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#   'local_site_name': 'IS 45',
#   'site_address': 'SCHOOL IS 45, 2351 1ST AVENUE',
#   'state': 'New York',
#   'county': 'New York',
#   'city': 'New York',
#   'cbsa_code': '35620',
# ...

# %%
# Select the properties we need.
air_quality = pd.DataFrame(air_quality, columns=['date_local', 'aqi'])
# Sorting data
# Sort data by date, remove duplicate rows and reset index.
air_quality = air_quality.sort_values(by=['date_local']).drop_duplicates().reset_index(drop=True)
air_quality.head(10)
# Out:
#    date_local  aqi
# 0  2021-01-01   28
# 1  2021-01-04   21
# 2  2021-01-07   17
# 3  2021-01-10   18
# 4  2021-01-13   69
# 5  2021-01-16   17
# 6  2021-01-16   14
# 7  2021-01-19   32
# 8  2021-01-22   27
# 9  2021-01-22   26

# %% [markdown]
# ### Covert data type

# %%
# View Data Introduction.
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_local  156 non-null    object
#  1   aqi         156 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.6+ KB

# %%
# Convert date_local column to a datetime
air_quality.date_local=pd.to_datetime(air_quality.date_local)
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_local  156 non-null    datetime64[ns]
#  1   aqi         156 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.6 KB

# %% [markdown]
# ### Check for miss values

# %%
# Checking for total null values.
air_quality.isna().sum()
# Out:
# date_local    0
# aqi           0
# dtype: int64

# %% [markdown]
# There's no missing value.
# ### Statistical distribution

# %%
# Show some simple distribution statistics.
air_quality.describe()
# Out:
#               aqi
# count  156.000000
# mean    30.653846
# std     15.760160
# min      6.000000
# 25%     18.000000
# 50%     28.000000
# 75%     37.250000
# max     78.000000

# %% [markdown]
# The maximum value of the numerical data is far from 75%, which indicates that we may have outliers.

# %% [markdown]
# ### BoxPlot and LinePlot

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
plt.subplots(figsize = (3,5))
# Plot the box plot for aqi
sns.boxplot(y = 'aqi', data = air_quality)
# give the plot a title
plt.title('Boxplot of aqi')
plt.show();

# %% [markdown]
# Since the percentage of outliers is very low, we choose to remove them.

# %%
# Detecting the outliers using IQR and removing them.
# IQR
Q1 = np.percentile(air_quality['aqi'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(air_quality['aqi'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
# Upper bound
upper = np.where(air_quality['aqi'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(air_quality['aqi'] <= (Q1-1.5*IQR))
# Removing the Outliers
air_quality.drop(upper[0], inplace = True)
air_quality.drop(lower[0], inplace = True)

# %%
# Sett the plot style
sns.set_style("darkgrid")
# Set the plot size
fig, ax = plt.subplots(figsize = (17, 7))
# Plot the line plot for aqi
# .dt.date will remove the time component for x axis
sns.pointplot(ax = ax, x=air_quality.date_local.dt.date, y='aqi', data=air_quality)
# Reduce the number of x-axis labels displayed
xticks=ax.xaxis.get_major_ticks()
for i in range(len(xticks)):
    if i%5!=1:
        xticks[i].set_visible(False)
# Rotate the label 45 degrees
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)
# Name the x and y axis
plt.xlabel('Date')
plt.ylabel('Api')
# give the plot a title
plt.title('Line plot of air quality')
plt.show();

# %% [markdown]
# The time series plot of aqi does not show a clear trend. Its effect on aqi can be determined later based on weather data.

# %% [markdown]
# ## EDA Summary

# %% [markdown]
# In the above EDA, we analyzed two datasets, weather and AQI, separately.
# - For the weather dataset.
# 1. Changed the date property to datetime format, and converted DailyPrecipitation and DailySnowfall to float format for subsequent calculations.
# 2. Checked for missing values.
# 3. Statistical analysis of the dataset reveals that the maximum value of some value variables is much larger than the upper quartile, and these values may have outliers, which will be further processed later.
# 4. Create a box line plot and process the outliers accordingly.
# 5. Plot a time series graph to analyze the trend of the variable.
# - For the AQI dataset.
# 1. Sort the data set by time and select aqi as the numerical variable.
# 2. Convert the date variable to datetime format for subsequent processing of the data.
# 3. Check for missing values.
# 4. Perform statistical analysis on the dataset and find that the maximum value of some value variables is much larger than the upper quartile, and these values may have outliers, which are further processed later.
# 5. Create box line plots and process the outliers accordingly.
# 6. Plot the time series graph of aqi.

# %% [markdown]
# ## Feature Engineering
# Convert numerical data to categorical variable for aqi

# %%
# Set aqi degree index value and name
bins=[0, 50, 100, 150, 200, 300, 999]
labels=['Good', 'Moderate', 'Unhealthy of Sensitive', 'Unhealthy', 'Very Unhealthy', 'Hazardous']
# Use .cut to divide the aqi values into levels according to the set range
air_quality['aqi_level']=pd.cut(air_quality['aqi'],bins,labels=labels)
air_quality.head(10)
# Out:
#    date_local  aqi aqi_level
# 0  2021-01-01   28      Good
# 1  2021-01-04   21      Good
# 2  2021-01-07   17      Good
# 3  2021-01-10   18      Good
# 5  2021-01-16   17      Good
# 6  2021-01-16   14      Good
# 7  2021-01-19   32      Good
# 8  2021-01-22   27      Good
# 9  2021-01-22   26      Good
# 10 2021-01-25   18      Good

# %% [markdown]
# Groups aqi by month and level to calculate the number of each aqi level for each month.

# %%
# Grouping and counting
counted_aqi = air_quality.groupby([(air_quality.date_local.dt.month)]).aqi_level.value_counts().rename('counts')
# Name index
counted_aqi.index.names = ["month", "aqi_level"]
# Removing row of 0 and coverting series to dataframe
counted_aqi[counted_aqi!=0].to_frame()
# Out:
#                  counts
# month aqi_level
# 1     Good           13
# 2     Good            9
#       Moderate        1
# 3     Good            8
#       Moderate        1
# 4     Good           13
#       Moderate        1
# 5     Good           13
#       Moderate        2
# 6     Good           11
#       Moderate        3
# 7     Good            8
#       Moderate        2
# 8     Good           10
#       Moderate        3
# 9     Good           15
# 10    Good           16
# 11    Good           10
#       Moderate        3
# 12    Good            7
#       Moderate        3

# %% [markdown]
# ### Plotting interactive bar diagrams with cufflinks
#
# Cufflinks is a new visualization toolkit for Python. Its best features are: easy to use, nice graphics, and little code. One can draw very nice graphics with just one or two lines of code. So we use it to create a Bar Plot of api level groupby month.

# %%
# !pip install cufflinks

# %%
pip install chart_studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from plotly import __version__
import cufflinks as cf
  
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# to get the connection
init_notebook_mode(connected = True)
  
# plotly also serves online,
# but we are using just a sample
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
# Use .unstack() to transform dataframe from long to wide for plotting
counted_aqi.unstack().iplot(kind='bar', title='Bar plot of air quality level numbers',xTitle='Date',yTitle='Number of aqi levels')
# Out:
# <div>                            <div id="05ba2a97-0b51-4b3a-8cf8-fc967d08e5c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Predictive Model

# %%
# Combine aqi and weather data based on date.
aqi = air_quality
mearge_data = pd.merge(aqi, 
                       weather,
                       how='inner',
                       left_on=['date_local'],
                       right_on=['DATE']).drop('aqi_level', axis=1)
data = mearge_data.drop('DATE', axis=1)
data.head()
# Out:
#   date_local  aqi  DailyAverageDewPointTemperature  \
# 0 2021-01-01   28                             27.0
# 1 2021-01-04   21                             31.0
# 2 2021-01-07   17                             20.0
# 3 2021-01-10   18                             18.0
# 4 2021-01-16   17                             35.0
#
#    DailyAverageDryBulbTemperature  DailyAverageRelativeHumidity  \
# 0                            37.0                          69.0
# 1                            39.0                          77.0
# 2                            36.0                          55.0
# 3                            35.0                          51.0
# 4                            42.0                          77.0
#
#    DailyAverageSeaLevelPressure  DailyAverageStationPressure  \
# 0                         30.36                        30.15
# 1                         29.96                        29.80
# 2                         30.08                        29.93
# ...

# %%
# Delete date_local
notime_data = data.drop('date_local', axis=1)
notime_data.head()
# Out:
#    aqi  DailyAverageDewPointTemperature  DailyAverageDryBulbTemperature  \
# 0   28                             27.0                            37.0
# 1   21                             31.0                            39.0
# 2   17                             20.0                            36.0
# 3   18                             18.0                            35.0
# 4   17                             35.0                            42.0
#
#    DailyAverageRelativeHumidity  DailyAverageSeaLevelPressure  \
# 0                          69.0                         30.36
# 1                          77.0                         29.96
# 2                          55.0                         30.08
# 3                          51.0                         30.19
# 4                          77.0                         29.46
#
#    DailyAverageStationPressure  DailyAverageWetBulbTemperature  \
# 0                        30.15                            33.0
# ...

# %%
# Load the LogisticRegression() function and preprocessing function from sklearn's 'linear_model' sub-library
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

zscore = preprocessing.StandardScaler()
# zscore Standardization
zscore = zscore.fit_transform(notime_data)
zscore
# Out:
# array([[-0.12727375, -0.94257061, -1.29799284, ...,  0.45514859,
#         -0.99018501, -0.44529573],
#        [-0.61013677, -0.72528972, -1.17677286, ..., -0.23107792,
#         -1.70288878, -0.44529573],
#        [-0.8860585 , -1.32281216, -1.35860283, ..., -0.25395213,
#          1.04611146,  0.17260649],
#        ...,
#        [ 1.73519789, -1.15985149, -1.29799284, ..., -0.25395213,
#          0.43522252, -0.03336092],
#        [ 2.4250022 , -0.07344706, -0.75250292, ..., -0.19676659,
#         -0.27748125, -1.26916535],
#        [ 2.35602177, -0.07344706, -0.75250292, ..., -0.19676659,
#         -0.27748125, -1.26916535]])

# %%
# Change zscore to DataFrame
data_zscore = pd.DataFrame(zscore,index=notime_data.index,columns=notime_data.columns)
data_zscore
# Out:
#           aqi  DailyAverageDewPointTemperature  \
# 0   -0.127274                        -0.942571
# 1   -0.610137                        -0.725290
# 2   -0.886058                        -1.322812
# 3   -0.817078                        -1.431453
# 4   -0.886058                        -0.508009
# ..        ...                              ...
# 137 -0.196254                        -0.562329
# 138 -0.265235                        -0.508009
# 139  1.735198                        -1.159851
# 140  2.425002                        -0.073447
# 141  2.356022                        -0.073447
#
#      DailyAverageDryBulbTemperature  DailyAverageRelativeHumidity  \
# 0                         -1.297993                      0.358024
# 1                         -1.176773                      0.883496
# 2                         -1.358603                     -0.561552
# 3                         -1.419213                     -0.824288
# ...

# %%
# A randomly selected 80% of the data from the dataset is used as training data
train = data_zscore.sample(frac = 0.8)
train
# Out:
#           aqi  DailyAverageDewPointTemperature  \
# 58  -0.679117                        -0.073447
# 68   1.597237                         1.393199
# 66  -0.334215                         0.741356
# 81  -0.817078                         1.284558
# 96  -0.265235                         1.067278
# ..        ...                              ...
# 136 -1.299941                        -1.268492
# 106 -0.265235                         0.415435
# 1   -0.610137                        -0.725290
# 35  -0.058293                         0.306794
# 98   0.217628                         1.121598
#
#      DailyAverageDryBulbTemperature  DailyAverageRelativeHumidity  \
# 58                         0.035427                     -0.101764
# 68                         1.368847                      0.555076
# 66                         0.883967                      0.029604
# 81                         1.187017                      0.817812
# ...

# %%
# The rest of the data is used as test data.
test = data_zscore.drop(train['aqi'].index)
test = test.dropna(axis=0, how='any')
test
# Out:
#           aqi  DailyAverageDewPointTemperature  \
# 11  -1.024019                        -1.866014
# 13  -1.024019                        -1.159851
# 14  -1.368922                        -1.159851
# 16   1.597237                        -1.159851
# 18   1.390296                        -1.051211
# 20  -0.127274                        -0.833930
# 22  -0.541156                        -0.290728
# 28  -0.127274                        -1.540093
# 29   2.425002                         0.143834
# 31  -1.230961                        -1.214172
# 32  -1.230961                        -0.779610
# 33  -0.610137                        -0.616649
# 47  -0.334215                         0.469755
# 55   1.597237                         0.578396
# 57   0.700491                         0.361115
# 70  -0.265235                         0.361115
# 71   1.183354                         1.393199
# 75  -1.161980                         0.741356
# 80   1.459276                         1.338879
# ...

# %%
# Define a vector containing the names of the attributes to use
predictors = ['DailyAverageDewPointTemperature', 'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity', 
                        'DailyAverageSeaLevelPressure', 'DailyAverageStationPressure', 'DailyAverageWetBulbTemperature', 
                        'DailyAverageWindSpeed','DailyPrecipitation', 'DailySnowfall', 'DailySustainedWindDirection', 'DailySustainedWindSpeed']

# Create a subset of the training data using the selected explanatory variables
X_train = train[predictors].values

# Create a subset of the testing data using the selected explanatory variables
X_test = test[predictors].values

# Isolate the response indicator for the training data
Y_train = train['aqi'].values

# Sanity check on training data
X_train[:5]
# Out:
# array([[-0.07344706,  0.03542697, -0.1017639 ,  0.07683441, -0.03089831,
#         -0.0184718 ,  1.89081788,  1.1413751 ,  1.1413751 , -1.29562948,
#          2.02631314],
#        [ 1.39319893,  1.36884677,  0.55507583, -1.53953399, -1.49341811,
#          1.4241761 , -0.52226905, -0.25395213, -0.25395213,  0.3334077 ,
#         -0.03336092],
#        [ 0.74135626,  0.88396684,  0.02960404, -1.1859534 , -1.14039609,
#          0.83400196, -0.16030601, -0.25395213, -0.25395213,  1.04611146,
#         -0.23932832],
#        [ 1.28455848,  1.1870168 ,  0.81781172, -0.17572315, -0.08133002,
#          1.29302629,  0.1212208 , -0.21964081, -0.21964081,  0.43522252,
#         -0.23932832],
#        [ 1.0672776 ,  0.82335685,  1.01486364,  0.93553013,  0.92730432,
#          1.03072667, -0.80379586, -0.25395213, -0.25395213, -1.39744431,
#         -0.85723054]])

# %%
# Sanity check on response indicator
Y_train[:5]
# Out:
# array([-0.6791172 ,  1.59723703, -0.33421505, -0.81707807, -0.26523462])

# %%
# Use the LogisticRegression() method for this model
model = LogisticRegression()

# Fit the model
model.fit(X_train, Y_train.astype('int'))
# Out:
# LogisticRegression()

# %%
# Calculate the accuracy of the model relative to the training data set
model.score(X_train, Y_train.astype('int'))
# Out:
# 0.7631578947368421

# %%
# Examine the model coefficients for the explanatory variables
print(predictors)
model.coef_
# Out:
# ['DailyAverageDewPointTemperature', 'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity', 'DailyAverageSeaLevelPressure', 'DailyAverageStationPressure', 'DailyAverageWetBulbTemperature', 'DailyAverageWindSpeed', 'DailyPrecipitation', 'DailySnowfall', 'DailySustainedWindDirection', 'DailySustainedWindSpeed']
# array([[-0.18589226, -0.04482216, -0.22296802, -0.21136066, -0.06310826,
#         -0.03089802,  1.16370885, -0.56837314, -0.56837314, -0.15361854,
#          0.26693406],
#        [ 0.10380757, -0.55285053, -0.5169495 ,  0.24100386, -0.02695442,
#          0.54205398, -0.06475577,  0.6732601 ,  0.6732601 , -0.25119307,
#         -0.4453841 ],
#        [ 0.03121118,  0.79318559,  0.08746248,  0.04566473,  0.1597129 ,
#         -0.3542472 , -0.70502885,  0.05053011,  0.05053011,  0.238128  ,
#          1.16990779],
#        [ 0.05087352, -0.1955129 ,  0.65245504, -0.07530793, -0.06965022,
#         -0.15690876, -0.39392423, -0.15541708, -0.15541708,  0.16668361,
# ...

# %%
# Generate predictions for the test data using our new model
Y_predict = model.predict(X_test)
Y_predict[:10]
# Out:
# array([-1, -1, -1,  0,  0,  0,  0,  0,  1, -1])

# %% [markdown]
# ## Correlation

# %% [markdown]
# The correlation coefficient is an indicator of the degree of linear correlation between two variables (the square of the correlation coefficient is called the coefficient of determination). Correlation analysis refers to the analysis of variables to determine the degree of correlation between two variable factors, and then to influence the other factor by guiding one of them.
# There are three main methods commonly used to measure correlation between variables.
#
# - Pearson correlation coefficient: i.e. Pearson correlation coefficient, which is used to measure the correlation coefficient between two continuous random variables.
# - Spearman correlation coefficient: i.e., Spearman correlation coefficient, which is a rank correlation coefficient. It is solved according to the ranking position of the original data and is also defined as the Pearson correlation coefficient between rank variables.
# - Kendall correlation coefficient: i.e., Kendall correlation coefficient, which is also a rank correlation coefficient and is often calculated for ordered categorical variables.
#
# Because our dataset has all continuous numeric variables except for the date variable. So we will use Pearson correlation coefficient correlation coefficient.

# %% [markdown]
# For the correlation analysis, there are two values to note. One is the correlation coefficient r and the other is the significance level p. The relationship between the two is such that the r value can only be referred to when p is less than 0.05 (or 0.01), and not just the r value. Assuming p=0.02 and r=0.8, the two sets of data are considered to have a highly linear relationship. Assuming p=0.5 and r=0.8, it is considered that the two sets of data cannot be compared in correlation (the correlation performance at this point may be coincidental).
#
# In general, we consider that:
# - an absolute value of r of 0.3, when no correlation exists;
# - the absolute value of r is greater than 0.3 and less than 0.5, at which point a low correlation exists;
# - the absolute value of r is greater than 0.5 and less than 0.8, at which point there is a significant correlation;
# - the absolute value of r is greater than 0.8, at which time there exists a high correlation.

# %% [markdown]
# ### Pearson

# %%
import scipy.stats as stats

r,p = stats.pearsonr(data['DailyAverageDewPointTemperature'],data['aqi'])  # he correlation coefficient and the significance level
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.442，the significance level p is  0.000

# %%
r,p = stats.pearsonr(data['DailyAverageDryBulbTemperature'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.423，the significance level p is  0.000

# %%
r,p = stats.pearsonr(data['DailyAverageRelativeHumidity'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.249，the significance level p is  0.003

# %%
r,p = stats.pearsonr(data['DailyAverageSeaLevelPressure'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.164，the significance level p is  0.051

# %%
r,p = stats.pearsonr(data['DailyAverageStationPressure'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.182，the significance level p is  0.030

# %%
r,p = stats.pearsonr(data['DailyAverageWetBulbTemperature'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.424，the significance level p is  0.000

# %%
r,p = stats.pearsonr(data['DailyAverageWindSpeed'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is -0.438，the significance level p is  0.000

# %%
r,p = stats.pearsonr(data['DailyPrecipitation'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.026，the significance level p is  0.756

# %%
r,p = stats.pearsonr(data['DailySnowfall'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.026，the significance level p is  0.756

# %%
r,p = stats.pearsonr(data['DailySustainedWindDirection'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is  0.008，the significance level p is  0.921

# %%
r,p = stats.pearsonr(data['DailySustainedWindSpeed'],data['aqi'])
print('The correlation coefficient r is %6.3f，the significance level p is %6.3f'%(r,p))
# Out:
# The correlation coefficient r is -0.259，the significance level p is  0.002

# %% [markdown]
# As we can see, for daily average sea level pressure, daily precipitation daily snowfall and daily sustained wind direction, there is no correlation with aqi. This is because the significance level p between them is greater than 0.05.
#
# For daily average dew point temperature, daily average dry bulb temperature, daily average wet bulb temperature and daily average wind speed, there is low correlation with aqi.This is because the absolute values of their correlation coefficients range from 0.3 to 0.5. Among them, daily average wind speed is negatively correlated with aqi and all others are positively correlated with aqi.
#
# For daily average relative humidity, daily average seaLevel pressure, daily average station pressure, daily precipitation, daily snowfall, daily sustained wind direction and daily sustained wind speed, there is no correlation with aqi. This is because the absolute value of their correlation coefficients is less than 0.3.

# %% [markdown]
# ## Conclusions
#
# We find that temperature-related data (e.g., dew point temperature, dry bulb temperature, wet bulb temperature) reach very small values in winter and very large values in summer. Humidity-related data (e.g., relative humidity) fluctuate throughout the year, with large fluctuations around March and small fluctuations around September. Pressure-related data (e.g., sea level pressure, station pressure) are stable throughout the year, with very small fluctuations. Wind speeds are higher in winter and lower in summer. Sustained wind speeds are higher in April and December and lower in October. Sustained wind direction fluctuates significantly throughout the year. Precipitation and snowfall tend to zero for the most part, with isolated periods producing anomalous highs.
# There is no clear trend in New York's AQI data, with multiple peaks in the AQI during the summer and winter months.
# There is a weak correlation between temperature and wind speed and AQI. a positive correlation between AQI and temperature and a negative correlation with wind speed.
