# %% [markdown]
# # Data Extraction and Processing for Chess Tournament Analysis
# Introduction
# In this project, we are tasked with extracting and processing data from a text file containing information about a chess tournament. The main goal is to parse the player data from the provided text file and analyze it to derive insights such as the average pre-tournament chess rating of opponents.

# %%
#Import the required libraries
import numpy as np
import pandas as pd
import re

#Opening text file in read mode
text_file = open("tournamentinfo.txt", "r")
#Reading whole file to a string
data = text_file.read()
#Closing file
text_file.close()
 
print(data)
# Out:
# -----------------------------------------------------------------------------------------
#  Pair | Player Name                     |Total|Round|Round|Round|Round|Round|Round|Round|
#  Num  | USCF ID / Rtg (Pre->Post)       | Pts |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
# -----------------------------------------------------------------------------------------
#     1 | GARY HUA                        |6.0  |W  39|W  21|W  18|W  14|W   7|D  12|D   4|
#    ON | 15445895 / R: 1794   ->1817     |N:2  |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#     2 | DAKSHESH DARURI                 |6.0  |W  63|W  58|L   4|W  17|W  16|W  20|W   7|
#    MI | 14598900 / R: 1553   ->1663     |N:2  |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#     3 | ADITYA BAJAJ                    |6.0  |L   8|W  61|W  25|W  21|W  11|W  13|W  12|
#    MI | 14959604 / R: 1384   ->1640     |N:2  |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#     4 | PATRICK H SCHILLING             |5.5  |W  23|D  28|W   2|W  26|D   5|W  19|D   1|
#    MI | 12616049 / R: 1716   ->1744     |N:2  |W    |B    |W    |B    |W    |B    |B    |
# -----------------------------------------------------------------------------------------
#     5 | HANSHI ZUO                      |5.5  |W  45|W  37|D  12|D  13|D   4|W  14|W  17|
#    MI | 14601533 / R: 1655   ->1690     |N:2  |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#     6 | HANSEN SONG                     |5.0  |W  34|D  29|L  11|W  35|D  10|W  27|W  21|
#    OH | 15055204 / R: 1686   ->1687     |N:3  |W    |B    |W    |B    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#     7 | GARY DEE SWATHELL               |5.0  |W  57|W  46|W  13|W  11|L   1|W   9|L   2|
#    MI | 11146376 / R: 1649   ->1673     |N:3  |W    |B    |W    |B    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#     8 | EZEKIEL HOUGHTON                |5.0  |W   3|W  32|L  14|L   9|W  47|W  28|W  19|
#    MI | 15142253 / R: 1641P17->1657P24  |N:3  |B    |W    |B    |W    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#     9 | STEFANO LEE                     |5.0  |W  25|L  18|W  59|W   8|W  26|L   7|W  20|
#    ON | 14954524 / R: 1411   ->1564     |N:2  |W    |B    |W    |B    |W    |B    |B    |
# -----------------------------------------------------------------------------------------
#    10 | ANVIT RAO                       |5.0  |D  16|L  19|W  55|W  31|D   6|W  25|W  18|
#    MI | 14150362 / R: 1365   ->1544     |N:3  |W    |W    |B    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    11 | CAMERON WILLIAM MC LEMAN        |4.5  |D  38|W  56|W   6|L   7|L   3|W  34|W  26|
#    MI | 12581589 / R: 1712   ->1696     |N:3  |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    12 | KENNETH J TACK                  |4.5  |W  42|W  33|D   5|W  38|H    |D   1|L   3|
#    MI | 12681257 / R: 1663   ->1670     |N:3  |W    |B    |W    |B    |     |W    |B    |
# -----------------------------------------------------------------------------------------
#    13 | TORRANCE HENRY JR               |4.5  |W  36|W  27|L   7|D   5|W  33|L   3|W  32|
#    MI | 15082995 / R: 1666   ->1662     |N:3  |B    |W    |B    |B    |W    |W    |B    |
# -----------------------------------------------------------------------------------------
#    14 | BRADLEY SHAW                    |4.5  |W  54|W  44|W   8|L   1|D  27|L   5|W  31|
#    MI | 10131499 / R: 1610   ->1618     |N:3  |W    |B    |W    |W    |B    |B    |W    |
# -----------------------------------------------------------------------------------------
#    15 | ZACHARY JAMES HOUGHTON          |4.5  |D  19|L  16|W  30|L  22|W  54|W  33|W  38|
#    MI | 15619130 / R: 1220P13->1416P20  |N:3  |B    |B    |W    |W    |B    |B    |W    |
# -----------------------------------------------------------------------------------------
#    16 | MIKE NIKITIN                    |4.0  |D  10|W  15|H    |W  39|L   2|W  36|U    |
#    MI | 10295068 / R: 1604   ->1613     |N:3  |B    |W    |     |B    |W    |B    |     |
# -----------------------------------------------------------------------------------------
#    17 | RONALD GRZEGORCZYK              |4.0  |W  48|W  41|L  26|L   2|W  23|W  22|L   5|
#    MI | 10297702 / R: 1629   ->1610     |N:3  |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    18 | DAVID SUNDEEN                   |4.0  |W  47|W   9|L   1|W  32|L  19|W  38|L  10|
#    MI | 11342094 / R: 1600   ->1600     |N:3  |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    19 | DIPANKAR ROY                    |4.0  |D  15|W  10|W  52|D  28|W  18|L   4|L   8|
#    MI | 14862333 / R: 1564   ->1570     |N:3  |W    |B    |W    |B    |W    |W    |B    |
# -----------------------------------------------------------------------------------------
#    20 | JASON ZHENG                     |4.0  |L  40|W  49|W  23|W  41|W  28|L   2|L   9|
#    MI | 14529060 / R: 1595   ->1569     |N:4  |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    21 | DINH DANG BUI                   |4.0  |W  43|L   1|W  47|L   3|W  40|W  39|L   6|
#    ON | 15495066 / R: 1563P22->1562     |N:3  |B    |W    |B    |W    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    22 | EUGENE L MCCLURE                |4.0  |W  64|D  52|L  28|W  15|H    |L  17|W  40|
#    MI | 12405534 / R: 1555   ->1529     |N:4  |W    |B    |W    |B    |     |W    |B    |
# -----------------------------------------------------------------------------------------
#    23 | ALAN BUI                        |4.0  |L   4|W  43|L  20|W  58|L  17|W  37|W  46|
#    ON | 15030142 / R: 1363   ->1371     |     |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    24 | MICHAEL R ALDRICH               |4.0  |L  28|L  47|W  43|L  25|W  60|W  44|W  39|
#    MI | 13469010 / R: 1229   ->1300     |N:4  |B    |W    |B    |B    |W    |W    |B    |
# -----------------------------------------------------------------------------------------
#    25 | LOREN SCHWIEBERT                |3.5  |L   9|W  53|L   3|W  24|D  34|L  10|W  47|
#    MI | 12486656 / R: 1745   ->1681     |N:4  |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    26 | MAX ZHU                         |3.5  |W  49|W  40|W  17|L   4|L   9|D  32|L  11|
#    ON | 15131520 / R: 1579   ->1564     |N:4  |B    |W    |B    |W    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#    27 | GAURAV GIDWANI                  |3.5  |W  51|L  13|W  46|W  37|D  14|L   6|U    |
#    MI | 14476567 / R: 1552   ->1539     |N:4  |W    |B    |W    |B    |W    |B    |     |
# -----------------------------------------------------------------------------------------
#    28 | SOFIA ADINA STANESCU-BELLU      |3.5  |W  24|D   4|W  22|D  19|L  20|L   8|D  36|
#    MI | 14882954 / R: 1507   ->1513     |N:3  |W    |W    |B    |W    |B    |B    |W    |
# -----------------------------------------------------------------------------------------
#    29 | CHIEDOZIE OKORIE                |3.5  |W  50|D   6|L  38|L  34|W  52|W  48|U    |
#    MI | 15323285 / R: 1602P6 ->1508P12  |N:4  |B    |W    |B    |W    |W    |B    |     |
# -----------------------------------------------------------------------------------------
#    30 | GEORGE AVERY JONES              |3.5  |L  52|D  64|L  15|W  55|L  31|W  61|W  50|
#    ON | 12577178 / R: 1522   ->1444     |     |W    |B    |B    |W    |W    |B    |B    |
# -----------------------------------------------------------------------------------------
#    31 | RISHI SHETTY                    |3.5  |L  58|D  55|W  64|L  10|W  30|W  50|L  14|
#    MI | 15131618 / R: 1494   ->1444     |     |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    32 | JOSHUA PHILIP MATHEWS           |3.5  |W  61|L   8|W  44|L  18|W  51|D  26|L  13|
#    ON | 14073750 / R: 1441   ->1433     |N:4  |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    33 | JADE GE                         |3.5  |W  60|L  12|W  50|D  36|L  13|L  15|W  51|
#    MI | 14691842 / R: 1449   ->1421     |     |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    34 | MICHAEL JEFFERY THOMAS          |3.5  |L   6|W  60|L  37|W  29|D  25|L  11|W  52|
#    MI | 15051807 / R: 1399   ->1400     |     |B    |W    |B    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    35 | JOSHUA DAVID LEE                |3.5  |L  46|L  38|W  56|L   6|W  57|D  52|W  48|
#    MI | 14601397 / R: 1438   ->1392     |     |W    |W    |B    |W    |B    |B    |W    |
# -----------------------------------------------------------------------------------------
#    36 | SIDDHARTH JHA                   |3.5  |L  13|W  57|W  51|D  33|H    |L  16|D  28|
#    MI | 14773163 / R: 1355   ->1367     |N:4  |W    |B    |W    |B    |     |W    |B    |
# -----------------------------------------------------------------------------------------
#    37 | AMIYATOSH PWNANANDAM            |3.5  |B    |L   5|W  34|L  27|H    |L  23|W  61|
#    MI | 15489571 / R:  980P12->1077P17  |     |     |B    |W    |W    |     |B    |W    |
# -----------------------------------------------------------------------------------------
#    38 | BRIAN LIU                       |3.0  |D  11|W  35|W  29|L  12|H    |L  18|L  15|
#    MI | 15108523 / R: 1423   ->1439     |N:4  |W    |B    |W    |W    |     |B    |B    |
# -----------------------------------------------------------------------------------------
#    39 | JOEL R HENDON                   |3.0  |L   1|W  54|W  40|L  16|W  44|L  21|L  24|
#    MI | 12923035 / R: 1436P23->1413     |N:4  |B    |W    |B    |W    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#    40 | FOREST ZHANG                    |3.0  |W  20|L  26|L  39|W  59|L  21|W  56|L  22|
#    MI | 14892710 / R: 1348   ->1346     |     |B    |B    |W    |W    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#    41 | KYLE WILLIAM MURPHY             |3.0  |W  59|L  17|W  58|L  20|X    |U    |U    |
#    MI | 15761443 / R: 1403P5 ->1341P9   |     |B    |W    |B    |W    |     |     |     |
# -----------------------------------------------------------------------------------------
#    42 | JARED GE                        |3.0  |L  12|L  50|L  57|D  60|D  61|W  64|W  56|
#    MI | 14462326 / R: 1332   ->1256     |     |B    |W    |B    |B    |W    |W    |B    |
# -----------------------------------------------------------------------------------------
#    43 | ROBERT GLEN VASEY               |3.0  |L  21|L  23|L  24|W  63|W  59|L  46|W  55|
#    MI | 14101068 / R: 1283   ->1244     |     |W    |B    |W    |W    |B    |B    |W    |
# -----------------------------------------------------------------------------------------
#    44 | JUSTIN D SCHILLING              |3.0  |B    |L  14|L  32|W  53|L  39|L  24|W  59|
#    MI | 15323504 / R: 1199   ->1199     |     |     |W    |B    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    45 | DEREK YAN                       |3.0  |L   5|L  51|D  60|L  56|W  63|D  55|W  58|
#    MI | 15372807 / R: 1242   ->1191     |     |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    46 | JACOB ALEXANDER LAVALLEY        |3.0  |W  35|L   7|L  27|L  50|W  64|W  43|L  23|
#    MI | 15490981 / R:  377P3 ->1076P10  |     |B    |W    |B    |W    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#    47 | ERIC WRIGHT                     |2.5  |L  18|W  24|L  21|W  61|L   8|D  51|L  25|
#    MI | 12533115 / R: 1362   ->1341     |     |W    |B    |W    |B    |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    48 | DANIEL KHAIN                    |2.5  |L  17|W  63|H    |D  52|H    |L  29|L  35|
#    MI | 14369165 / R: 1382   ->1335     |     |B    |W    |     |B    |     |W    |B    |
# -----------------------------------------------------------------------------------------
#    49 | MICHAEL J MARTIN                |2.5  |L  26|L  20|D  63|D  64|W  58|H    |U    |
#    MI | 12531685 / R: 1291P12->1259P17  |     |W    |W    |B    |W    |B    |     |     |
# -----------------------------------------------------------------------------------------
#    50 | SHIVAM JHA                      |2.5  |L  29|W  42|L  33|W  46|H    |L  31|L  30|
#    MI | 14773178 / R: 1056   ->1111     |     |W    |B    |W    |B    |     |B    |W    |
# -----------------------------------------------------------------------------------------
#    51 | TEJAS AYYAGARI                  |2.5  |L  27|W  45|L  36|W  57|L  32|D  47|L  33|
#    MI | 15205474 / R: 1011   ->1097     |     |B    |W    |B    |W    |B    |W    |W    |
# -----------------------------------------------------------------------------------------
#    52 | ETHAN GUO                       |2.5  |W  30|D  22|L  19|D  48|L  29|D  35|L  34|
#    MI | 14918803 / R:  935   ->1092     |N:4  |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    53 | JOSE C YBARRA                   |2.0  |H    |L  25|H    |L  44|U    |W  57|U    |
#    MI | 12578849 / R: 1393   ->1359     |     |     |B    |     |W    |     |W    |     |
# -----------------------------------------------------------------------------------------
#    54 | LARRY HODGE                     |2.0  |L  14|L  39|L  61|B    |L  15|L  59|W  64|
#    MI | 12836773 / R: 1270   ->1200     |     |B    |B    |W    |     |W    |B    |W    |
# -----------------------------------------------------------------------------------------
#    55 | ALEX KONG                       |2.0  |L  62|D  31|L  10|L  30|B    |D  45|L  43|
#    MI | 15412571 / R: 1186   ->1163     |     |W    |B    |W    |B    |     |W    |B    |
# -----------------------------------------------------------------------------------------
#    56 | MARISA RICCI                    |2.0  |H    |L  11|L  35|W  45|H    |L  40|L  42|
#    MI | 14679887 / R: 1153   ->1140     |     |     |B    |W    |W    |     |B    |W    |
# -----------------------------------------------------------------------------------------
#    57 | MICHAEL LU                      |2.0  |L   7|L  36|W  42|L  51|L  35|L  53|B    |
#    MI | 15113330 / R: 1092   ->1079     |     |B    |W    |W    |B    |W    |B    |     |
# -----------------------------------------------------------------------------------------
#    58 | VIRAJ MOHILE                    |2.0  |W  31|L   2|L  41|L  23|L  49|B    |L  45|
#    MI | 14700365 / R:  917   -> 941     |     |W    |B    |W    |B    |W    |     |B    |
# -----------------------------------------------------------------------------------------
#    59 | SEAN M MC CORMICK               |2.0  |L  41|B    |L   9|L  40|L  43|W  54|L  44|
#    MI | 12841036 / R:  853   -> 878     |     |W    |     |B    |B    |W    |W    |B    |
# -----------------------------------------------------------------------------------------
#    60 | JULIA SHEN                      |1.5  |L  33|L  34|D  45|D  42|L  24|H    |U    |
#    MI | 14579262 / R:  967   -> 984     |     |W    |B    |B    |W    |B    |     |     |
# -----------------------------------------------------------------------------------------
#    61 | JEZZEL FARKAS                   |1.5  |L  32|L   3|W  54|L  47|D  42|L  30|L  37|
#    ON | 15771592 / R:  955P11-> 979P18  |     |B    |W    |B    |W    |B    |W    |B    |
# -----------------------------------------------------------------------------------------
#    62 | ASHWIN BALAJI                   |1.0  |W  55|U    |U    |U    |U    |U    |U    |
#    MI | 15219542 / R: 1530   ->1535     |     |B    |     |     |     |     |     |     |
# -----------------------------------------------------------------------------------------
#    63 | THOMAS JOSEPH HOSMER            |1.0  |L   2|L  48|D  49|L  43|L  45|H    |U    |
#    MI | 15057092 / R: 1175   ->1125     |     |W    |B    |W    |B    |B    |     |     |
# -----------------------------------------------------------------------------------------
#    64 | BEN LI                          |1.0  |L  22|D  30|L  31|D  49|L  46|L  42|L  54|
#    MI | 15006561 / R: 1163   ->1112     |     |B    |W    |W    |B    |W    |B    |B    |
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ## Extracting player information into data frames

# %%
# Separate out each player's information
a = re.split(r"\|\n\--+\n",data)

# Create a data frame containing players' information
playerinfo = pd.DataFrame(columns=['Name', 'State', 'Total Number of Points', 'Pre-Rating'])

# define a label variable
m = 0

# Traverse players' information and extract corresponding data
for n in range(0,len(a)):
    names = re.findall(r'\|\s+(.*?)\s+\|[0-9]',a[n])
    state = re.findall(r'\|\n\s+([A-Z]+)',a[n])
    total_nbr_point = re.findall(r'[0-9]\.[0-9]',a[n])
    pre_rating = re.findall(r'R:\s+([0-9]+)',a[n])
    # add the extracted information to the dataframe in order
    playerinfo.loc[m] = names + state + total_nbr_point + pre_rating
    m = m+1
# output dataframe
playerinfo.head()
# Out:
#                   Name State Total Number of Points Pre-Rating
# 0             GARY HUA    ON                    6.0       1794
# 1      DAKSHESH DARURI    MI                    6.0       1553
# 2         ADITYA BAJAJ    MI                    6.0       1384
# 3  PATRICK H SCHILLING    MI                    5.5       1716
# 4           HANSHI ZUO    MI                    5.5       1655

# %%
#Adding the "Average Pre Tournament Chess Rating of Opponents" column
playerinfo.insert(4, 'Average Pre Tournament Chess Rating of Opponents', np.NaN)
playerinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Name                                              64 non-null     object
#  1   State                                             64 non-null     object
#  2   Total Number of Points                            64 non-null     object
#  3   Pre-Rating                                        64 non-null     object
#  4   Average Pre Tournament Chess Rating of Opponents  0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 3.0+ KB

# %% [markdown]
# ## Extract and calculate the average of the opponents' pre-ratings

# %%
# convert str to a list
tournamentinfo = [data]

# %%
#Extracting the first row of each player's data
line1 = re.compile('\s+\d+\s\|\s(?P<Player_name>.+)\|(?P<total_points>[0-9]+[.][0-9])\s+\|(?P<R1_R>\w)\s+(?P<R1_O>\d{1,})?\|(?P<R2_R>\w)\s+(?P<R2_O>\d{1,})?\|(?P<R3_R>\w)\s+(?P<R3_O>\d{1,})?\|(?P<R4_R>\w)\s+(?P<R4_O>\d{1,})?\|(?P<R5_R>\w)\s+(?P<R5_O>\d{1,})?\|(?P<R6_R>\w)\s+(?P<R6_O>\d{1,})?\|(?P<R7_R>\w)\s+(?P<R7_O>\d{1,})?\|')
line1_result = [m.groupdict() for m in line1.finditer(tournamentinfo[0])]
line1_result
# Out:
# [{'Player_name': 'GARY HUA                        ',
#   'total_points': '6.0',
#   'R1_R': 'W',
#   'R1_O': '39',
#   'R2_R': 'W',
#   'R2_O': '21',
#   'R3_R': 'W',
#   'R3_O': '18',
#   'R4_R': 'W',
#   'R4_O': '14',
#   'R5_R': 'W',
#   'R5_O': '7',
#   'R6_R': 'D',
#   'R6_O': '12',
#   'R7_R': 'D',
#   'R7_O': '4'},
#  {'Player_name': 'DAKSHESH DARURI                 ',
#   'total_points': '6.0',
#   'R1_R': 'W',
#   'R1_O': '63',
#   'R2_R': 'W',
#   'R2_O': '58',
#   'R3_R': 'L',
#   'R3_O': '4',
#   'R4_R': 'W',
#   'R4_O': '17',
#   'R5_R': 'W',
#   'R5_O': '16',
#   'R6_R': 'W',
#   'R6_O': '20',
#   'R7_R': 'W',
#   'R7_O': '7'},
#  {'Player_name': 'ADITYA BAJAJ                    ',
#   'total_points': '6.0',
#   'R1_R': 'L',
#   'R1_O': '8',
#   'R2_R': 'W',
#   'R2_O': '61',
#   'R3_R': 'W',
#   'R3_O': '25',
#   'R4_R': 'W',
#   'R4_O': '21',
#   'R5_R': 'W',
#   'R5_O': '11',
#   'R6_R': 'W',
#   'R6_O': '13',
#   'R7_R': 'W',
#   'R7_O': '12'},
#  {'Player_name': 'PATRICK H SCHILLING             ',
#   'total_points': '5.5',
#   'R1_R': 'W',
#   'R1_O': '23',
#   'R2_R': 'D',
#   'R2_O': '28',
#   'R3_R': 'W',
#   'R3_O': '2',
#   'R4_R': 'W',
#   'R4_O': '26',
#   'R5_R': 'D',
#   'R5_O': '5',
#   'R6_R': 'W',
#   'R6_O': '19',
#   'R7_R': 'D',
#   'R7_O': '1'},
#  {'Player_name': 'HANSHI ZUO                      ',
#   'total_points': '5.5',
#   'R1_R': 'W',
#   'R1_O': '45',
#   'R2_R': 'W',
#   'R2_O': '37',
#   'R3_R': 'D',
#   'R3_O': '12',
#   'R4_R': 'D',
#   'R4_O': '13',
#   'R5_R': 'D',
#   'R5_O': '4',
#   'R6_R': 'W',
#   'R6_O': '14',
#   'R7_R': 'W',
#   'R7_O': '17'},
#  {'Player_name': 'HANSEN SONG                     ',
#   'total_points': '5.0',
#   'R1_R': 'W',
#   'R1_O': '34',
#   'R2_R': 'D',
#   'R2_O': '29',
#   'R3_R': 'L',
#   'R3_O': '11',
#   'R4_R': 'W',
#   'R4_O': '35',
#   'R5_R': 'D',
#   'R5_O': '10',
#   'R6_R': 'W',
#   'R6_O': '27',
#   'R7_R': 'W',
#   'R7_O': '21'},
#  {'Player_name': 'GARY DEE SWATHELL               ',
#   'total_points': '5.0',
#   'R1_R': 'W',
#   'R1_O': '57',
#   'R2_R': 'W',
#   'R2_O': '46',
#   'R3_R': 'W',
#   'R3_O': '13',
#   'R4_R': 'W',
#   'R4_O': '11',
#   'R5_R': 'L',
#   'R5_O': '1',
#   'R6_R': 'W',
#   'R6_O': '9',
#   'R7_R': 'L',
#   'R7_O': '2'},
#  {'Player_name': 'EZEKIEL HOUGHTON                ',
#   'total_points': '5.0',
#   'R1_R': 'W',
#   'R1_O': '3',
#   'R2_R': 'W',
#   'R2_O': '32',
#   'R3_R': 'L',
#   'R3_O': '14',
#   'R4_R': 'L',
#   'R4_O': '9',
#   'R5_R': 'W',
#   'R5_O': '47',
#   'R6_R': 'W',
#   'R6_O': '28',
#   'R7_R': 'W',
#   'R7_O': '19'},
#  {'Player_name': 'STEFANO LEE                     ',
#   'total_points': '5.0',
#   'R1_R': 'W',
#   'R1_O': '25',
#   'R2_R': 'L',
#   'R2_O': '18',
#   'R3_R': 'W',
#   'R3_O': '59',
#   'R4_R': 'W',
#   'R4_O': '8',
#   'R5_R': 'W',
#   'R5_O': '26',
#   'R6_R': 'L',
#   'R6_O': '7',
#   'R7_R': 'W',
#   'R7_O': '20'},
#  {'Player_name': 'ANVIT RAO                       ',
#   'total_points': '5.0',
#   'R1_R': 'D',
#   'R1_O': '16',
#   'R2_R': 'L',
#   'R2_O': '19',
#   'R3_R': 'W',
#   'R3_O': '55',
#   'R4_R': 'W',
#   'R4_O': '31',
#   'R5_R': 'D',
#   'R5_O': '6',
#   'R6_R': 'W',
#   'R6_O': '25',
#   'R7_R': 'W',
#   'R7_O': '18'},
#  {'Player_name': 'CAMERON WILLIAM MC LEMAN        ',
#   'total_points': '4.5',
#   'R1_R': 'D',
#   'R1_O': '38',
#   'R2_R': 'W',
#   'R2_O': '56',
#   'R3_R': 'W',
#   'R3_O': '6',
#   'R4_R': 'L',
#   'R4_O': '7',
#   'R5_R': 'L',
#   'R5_O': '3',
#   'R6_R': 'W',
#   'R6_O': '34',
#   'R7_R': 'W',
#   'R7_O': '26'},
#  {'Player_name': 'KENNETH J TACK                  ',
#   'total_points': '4.5',
#   'R1_R': 'W',
#   'R1_O': '42',
#   'R2_R': 'W',
#   'R2_O': '33',
#   'R3_R': 'D',
#   'R3_O': '5',
#   'R4_R': 'W',
#   'R4_O': '38',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'D',
#   'R6_O': '1',
#   'R7_R': 'L',
#   'R7_O': '3'},
#  {'Player_name': 'TORRANCE HENRY JR               ',
#   'total_points': '4.5',
#   'R1_R': 'W',
#   'R1_O': '36',
#   'R2_R': 'W',
#   'R2_O': '27',
#   'R3_R': 'L',
#   'R3_O': '7',
#   'R4_R': 'D',
#   'R4_O': '5',
#   'R5_R': 'W',
#   'R5_O': '33',
#   'R6_R': 'L',
#   'R6_O': '3',
#   'R7_R': 'W',
#   'R7_O': '32'},
#  {'Player_name': 'BRADLEY SHAW                    ',
#   'total_points': '4.5',
#   'R1_R': 'W',
#   'R1_O': '54',
#   'R2_R': 'W',
#   'R2_O': '44',
#   'R3_R': 'W',
#   'R3_O': '8',
#   'R4_R': 'L',
#   'R4_O': '1',
#   'R5_R': 'D',
#   'R5_O': '27',
#   'R6_R': 'L',
#   'R6_O': '5',
#   'R7_R': 'W',
#   'R7_O': '31'},
#  {'Player_name': 'ZACHARY JAMES HOUGHTON          ',
#   'total_points': '4.5',
#   'R1_R': 'D',
#   'R1_O': '19',
#   'R2_R': 'L',
#   'R2_O': '16',
#   'R3_R': 'W',
#   'R3_O': '30',
#   'R4_R': 'L',
#   'R4_O': '22',
#   'R5_R': 'W',
#   'R5_O': '54',
#   'R6_R': 'W',
#   'R6_O': '33',
#   'R7_R': 'W',
#   'R7_O': '38'},
#  {'Player_name': 'MIKE NIKITIN                    ',
#   'total_points': '4.0',
#   'R1_R': 'D',
#   'R1_O': '10',
#   'R2_R': 'W',
#   'R2_O': '15',
#   'R3_R': 'H',
#   'R3_O': None,
#   'R4_R': 'W',
#   'R4_O': '39',
#   'R5_R': 'L',
#   'R5_O': '2',
#   'R6_R': 'W',
#   'R6_O': '36',
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'RONALD GRZEGORCZYK              ',
#   'total_points': '4.0',
#   'R1_R': 'W',
#   'R1_O': '48',
#   'R2_R': 'W',
#   'R2_O': '41',
#   'R3_R': 'L',
#   'R3_O': '26',
#   'R4_R': 'L',
#   'R4_O': '2',
#   'R5_R': 'W',
#   'R5_O': '23',
#   'R6_R': 'W',
#   'R6_O': '22',
#   'R7_R': 'L',
#   'R7_O': '5'},
#  {'Player_name': 'DAVID SUNDEEN                   ',
#   'total_points': '4.0',
#   'R1_R': 'W',
#   'R1_O': '47',
#   'R2_R': 'W',
#   'R2_O': '9',
#   'R3_R': 'L',
#   'R3_O': '1',
#   'R4_R': 'W',
#   'R4_O': '32',
#   'R5_R': 'L',
#   'R5_O': '19',
#   'R6_R': 'W',
#   'R6_O': '38',
#   'R7_R': 'L',
#   'R7_O': '10'},
#  {'Player_name': 'DIPANKAR ROY                    ',
#   'total_points': '4.0',
#   'R1_R': 'D',
#   'R1_O': '15',
#   'R2_R': 'W',
#   'R2_O': '10',
#   'R3_R': 'W',
#   'R3_O': '52',
#   'R4_R': 'D',
#   'R4_O': '28',
#   'R5_R': 'W',
#   'R5_O': '18',
#   'R6_R': 'L',
#   'R6_O': '4',
#   'R7_R': 'L',
#   'R7_O': '8'},
#  {'Player_name': 'JASON ZHENG                     ',
#   'total_points': '4.0',
#   'R1_R': 'L',
#   'R1_O': '40',
#   'R2_R': 'W',
#   'R2_O': '49',
#   'R3_R': 'W',
#   'R3_O': '23',
#   'R4_R': 'W',
#   'R4_O': '41',
#   'R5_R': 'W',
#   'R5_O': '28',
#   'R6_R': 'L',
#   'R6_O': '2',
#   'R7_R': 'L',
#   'R7_O': '9'},
#  {'Player_name': 'DINH DANG BUI                   ',
#   'total_points': '4.0',
#   'R1_R': 'W',
#   'R1_O': '43',
#   'R2_R': 'L',
#   'R2_O': '1',
#   'R3_R': 'W',
#   'R3_O': '47',
#   'R4_R': 'L',
#   'R4_O': '3',
#   'R5_R': 'W',
#   'R5_O': '40',
#   'R6_R': 'W',
#   'R6_O': '39',
#   'R7_R': 'L',
#   'R7_O': '6'},
#  {'Player_name': 'EUGENE L MCCLURE                ',
#   'total_points': '4.0',
#   'R1_R': 'W',
#   'R1_O': '64',
#   'R2_R': 'D',
#   'R2_O': '52',
#   'R3_R': 'L',
#   'R3_O': '28',
#   'R4_R': 'W',
#   'R4_O': '15',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '17',
#   'R7_R': 'W',
#   'R7_O': '40'},
#  {'Player_name': 'ALAN BUI                        ',
#   'total_points': '4.0',
#   'R1_R': 'L',
#   'R1_O': '4',
#   'R2_R': 'W',
#   'R2_O': '43',
#   'R3_R': 'L',
#   'R3_O': '20',
#   'R4_R': 'W',
#   'R4_O': '58',
#   'R5_R': 'L',
#   'R5_O': '17',
#   'R6_R': 'W',
#   'R6_O': '37',
#   'R7_R': 'W',
#   'R7_O': '46'},
#  {'Player_name': 'MICHAEL R ALDRICH               ',
#   'total_points': '4.0',
#   'R1_R': 'L',
#   'R1_O': '28',
#   'R2_R': 'L',
#   'R2_O': '47',
#   'R3_R': 'W',
#   'R3_O': '43',
#   'R4_R': 'L',
#   'R4_O': '25',
#   'R5_R': 'W',
#   'R5_O': '60',
#   'R6_R': 'W',
#   'R6_O': '44',
#   'R7_R': 'W',
#   'R7_O': '39'},
#  {'Player_name': 'LOREN SCHWIEBERT                ',
#   'total_points': '3.5',
#   'R1_R': 'L',
#   'R1_O': '9',
#   'R2_R': 'W',
#   'R2_O': '53',
#   'R3_R': 'L',
#   'R3_O': '3',
#   'R4_R': 'W',
#   'R4_O': '24',
#   'R5_R': 'D',
#   'R5_O': '34',
#   'R6_R': 'L',
#   'R6_O': '10',
#   'R7_R': 'W',
#   'R7_O': '47'},
#  {'Player_name': 'MAX ZHU                         ',
#   'total_points': '3.5',
#   'R1_R': 'W',
#   'R1_O': '49',
#   'R2_R': 'W',
#   'R2_O': '40',
#   'R3_R': 'W',
#   'R3_O': '17',
#   'R4_R': 'L',
#   'R4_O': '4',
#   'R5_R': 'L',
#   'R5_O': '9',
#   'R6_R': 'D',
#   'R6_O': '32',
#   'R7_R': 'L',
#   'R7_O': '11'},
#  {'Player_name': 'GAURAV GIDWANI                  ',
#   'total_points': '3.5',
#   'R1_R': 'W',
#   'R1_O': '51',
#   'R2_R': 'L',
#   'R2_O': '13',
#   'R3_R': 'W',
#   'R3_O': '46',
#   'R4_R': 'W',
#   'R4_O': '37',
#   'R5_R': 'D',
#   'R5_O': '14',
#   'R6_R': 'L',
#   'R6_O': '6',
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'SOFIA ADINA STANESCU-BELLU      ',
#   'total_points': '3.5',
#   'R1_R': 'W',
#   'R1_O': '24',
#   'R2_R': 'D',
#   'R2_O': '4',
#   'R3_R': 'W',
#   'R3_O': '22',
#   'R4_R': 'D',
#   'R4_O': '19',
#   'R5_R': 'L',
#   'R5_O': '20',
#   'R6_R': 'L',
#   'R6_O': '8',
#   'R7_R': 'D',
#   'R7_O': '36'},
#  {'Player_name': 'CHIEDOZIE OKORIE                ',
#   'total_points': '3.5',
#   'R1_R': 'W',
#   'R1_O': '50',
#   'R2_R': 'D',
#   'R2_O': '6',
#   'R3_R': 'L',
#   'R3_O': '38',
#   'R4_R': 'L',
#   'R4_O': '34',
#   'R5_R': 'W',
#   'R5_O': '52',
#   'R6_R': 'W',
#   'R6_O': '48',
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'GEORGE AVERY JONES              ',
#   'total_points': '3.5',
#   'R1_R': 'L',
#   'R1_O': '52',
#   'R2_R': 'D',
#   'R2_O': '64',
#   'R3_R': 'L',
#   'R3_O': '15',
#   'R4_R': 'W',
#   'R4_O': '55',
#   'R5_R': 'L',
#   'R5_O': '31',
#   'R6_R': 'W',
#   'R6_O': '61',
#   'R7_R': 'W',
#   'R7_O': '50'},
#  {'Player_name': 'RISHI SHETTY                    ',
#   'total_points': '3.5',
#   'R1_R': 'L',
#   'R1_O': '58',
#   'R2_R': 'D',
#   'R2_O': '55',
#   'R3_R': 'W',
#   'R3_O': '64',
#   'R4_R': 'L',
#   'R4_O': '10',
#   'R5_R': 'W',
#   'R5_O': '30',
#   'R6_R': 'W',
#   'R6_O': '50',
#   'R7_R': 'L',
#   'R7_O': '14'},
#  {'Player_name': 'JOSHUA PHILIP MATHEWS           ',
#   'total_points': '3.5',
#   'R1_R': 'W',
#   'R1_O': '61',
#   'R2_R': 'L',
#   'R2_O': '8',
#   'R3_R': 'W',
#   'R3_O': '44',
#   'R4_R': 'L',
#   'R4_O': '18',
#   'R5_R': 'W',
#   'R5_O': '51',
#   'R6_R': 'D',
#   'R6_O': '26',
#   'R7_R': 'L',
#   'R7_O': '13'},
#  {'Player_name': 'JADE GE                         ',
#   'total_points': '3.5',
#   'R1_R': 'W',
#   'R1_O': '60',
#   'R2_R': 'L',
#   'R2_O': '12',
#   'R3_R': 'W',
#   'R3_O': '50',
#   'R4_R': 'D',
#   'R4_O': '36',
#   'R5_R': 'L',
#   'R5_O': '13',
#   'R6_R': 'L',
#   'R6_O': '15',
#   'R7_R': 'W',
#   'R7_O': '51'},
#  {'Player_name': 'MICHAEL JEFFERY THOMAS          ',
#   'total_points': '3.5',
#   'R1_R': 'L',
#   'R1_O': '6',
#   'R2_R': 'W',
#   'R2_O': '60',
#   'R3_R': 'L',
#   'R3_O': '37',
#   'R4_R': 'W',
#   'R4_O': '29',
#   'R5_R': 'D',
#   'R5_O': '25',
#   'R6_R': 'L',
#   'R6_O': '11',
#   'R7_R': 'W',
#   'R7_O': '52'},
#  {'Player_name': 'JOSHUA DAVID LEE                ',
#   'total_points': '3.5',
#   'R1_R': 'L',
#   'R1_O': '46',
#   'R2_R': 'L',
#   'R2_O': '38',
#   'R3_R': 'W',
#   'R3_O': '56',
#   'R4_R': 'L',
#   'R4_O': '6',
#   'R5_R': 'W',
#   'R5_O': '57',
#   'R6_R': 'D',
#   'R6_O': '52',
#   'R7_R': 'W',
#   'R7_O': '48'},
#  {'Player_name': 'SIDDHARTH JHA                   ',
#   'total_points': '3.5',
#   'R1_R': 'L',
#   'R1_O': '13',
#   'R2_R': 'W',
#   'R2_O': '57',
#   'R3_R': 'W',
#   'R3_O': '51',
#   'R4_R': 'D',
#   'R4_O': '33',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '16',
#   'R7_R': 'D',
#   'R7_O': '28'},
#  {'Player_name': 'AMIYATOSH PWNANANDAM            ',
#   'total_points': '3.5',
#   'R1_R': 'B',
#   'R1_O': None,
#   'R2_R': 'L',
#   'R2_O': '5',
#   'R3_R': 'W',
#   'R3_O': '34',
#   'R4_R': 'L',
#   'R4_O': '27',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '23',
#   'R7_R': 'W',
#   'R7_O': '61'},
#  {'Player_name': 'BRIAN LIU                       ',
#   'total_points': '3.0',
#   'R1_R': 'D',
#   'R1_O': '11',
#   'R2_R': 'W',
#   'R2_O': '35',
#   'R3_R': 'W',
#   'R3_O': '29',
#   'R4_R': 'L',
#   'R4_O': '12',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '18',
#   'R7_R': 'L',
#   'R7_O': '15'},
#  {'Player_name': 'JOEL R HENDON                   ',
#   'total_points': '3.0',
#   'R1_R': 'L',
#   'R1_O': '1',
#   'R2_R': 'W',
#   'R2_O': '54',
#   'R3_R': 'W',
#   'R3_O': '40',
#   'R4_R': 'L',
#   'R4_O': '16',
#   'R5_R': 'W',
#   'R5_O': '44',
#   'R6_R': 'L',
#   'R6_O': '21',
#   'R7_R': 'L',
#   'R7_O': '24'},
#  {'Player_name': 'FOREST ZHANG                    ',
#   'total_points': '3.0',
#   'R1_R': 'W',
#   'R1_O': '20',
#   'R2_R': 'L',
#   'R2_O': '26',
#   'R3_R': 'L',
#   'R3_O': '39',
#   'R4_R': 'W',
#   'R4_O': '59',
#   'R5_R': 'L',
#   'R5_O': '21',
#   'R6_R': 'W',
#   'R6_O': '56',
#   'R7_R': 'L',
#   'R7_O': '22'},
#  {'Player_name': 'KYLE WILLIAM MURPHY             ',
#   'total_points': '3.0',
#   'R1_R': 'W',
#   'R1_O': '59',
#   'R2_R': 'L',
#   'R2_O': '17',
#   'R3_R': 'W',
#   'R3_O': '58',
#   'R4_R': 'L',
#   'R4_O': '20',
#   'R5_R': 'X',
#   'R5_O': None,
#   'R6_R': 'U',
#   'R6_O': None,
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'JARED GE                        ',
#   'total_points': '3.0',
#   'R1_R': 'L',
#   'R1_O': '12',
#   'R2_R': 'L',
#   'R2_O': '50',
#   'R3_R': 'L',
#   'R3_O': '57',
#   'R4_R': 'D',
#   'R4_O': '60',
#   'R5_R': 'D',
#   'R5_O': '61',
#   'R6_R': 'W',
#   'R6_O': '64',
#   'R7_R': 'W',
#   'R7_O': '56'},
#  {'Player_name': 'ROBERT GLEN VASEY               ',
#   'total_points': '3.0',
#   'R1_R': 'L',
#   'R1_O': '21',
#   'R2_R': 'L',
#   'R2_O': '23',
#   'R3_R': 'L',
#   'R3_O': '24',
#   'R4_R': 'W',
#   'R4_O': '63',
#   'R5_R': 'W',
#   'R5_O': '59',
#   'R6_R': 'L',
#   'R6_O': '46',
#   'R7_R': 'W',
#   'R7_O': '55'},
#  {'Player_name': 'JUSTIN D SCHILLING              ',
#   'total_points': '3.0',
#   'R1_R': 'B',
#   'R1_O': None,
#   'R2_R': 'L',
#   'R2_O': '14',
#   'R3_R': 'L',
#   'R3_O': '32',
#   'R4_R': 'W',
#   'R4_O': '53',
#   'R5_R': 'L',
#   'R5_O': '39',
#   'R6_R': 'L',
#   'R6_O': '24',
#   'R7_R': 'W',
#   'R7_O': '59'},
#  {'Player_name': 'DEREK YAN                       ',
#   'total_points': '3.0',
#   'R1_R': 'L',
#   'R1_O': '5',
#   'R2_R': 'L',
#   'R2_O': '51',
#   'R3_R': 'D',
#   'R3_O': '60',
#   'R4_R': 'L',
#   'R4_O': '56',
#   'R5_R': 'W',
#   'R5_O': '63',
#   'R6_R': 'D',
#   'R6_O': '55',
#   'R7_R': 'W',
#   'R7_O': '58'},
#  {'Player_name': 'JACOB ALEXANDER LAVALLEY        ',
#   'total_points': '3.0',
#   'R1_R': 'W',
#   'R1_O': '35',
#   'R2_R': 'L',
#   'R2_O': '7',
#   'R3_R': 'L',
#   'R3_O': '27',
#   'R4_R': 'L',
#   'R4_O': '50',
#   'R5_R': 'W',
#   'R5_O': '64',
#   'R6_R': 'W',
#   'R6_O': '43',
#   'R7_R': 'L',
#   'R7_O': '23'},
#  {'Player_name': 'ERIC WRIGHT                     ',
#   'total_points': '2.5',
#   'R1_R': 'L',
#   'R1_O': '18',
#   'R2_R': 'W',
#   'R2_O': '24',
#   'R3_R': 'L',
#   'R3_O': '21',
#   'R4_R': 'W',
#   'R4_O': '61',
#   'R5_R': 'L',
#   'R5_O': '8',
#   'R6_R': 'D',
#   'R6_O': '51',
#   'R7_R': 'L',
#   'R7_O': '25'},
#  {'Player_name': 'DANIEL KHAIN                    ',
#   'total_points': '2.5',
#   'R1_R': 'L',
#   'R1_O': '17',
#   'R2_R': 'W',
#   'R2_O': '63',
#   'R3_R': 'H',
#   'R3_O': None,
#   'R4_R': 'D',
#   'R4_O': '52',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '29',
#   'R7_R': 'L',
#   'R7_O': '35'},
#  {'Player_name': 'MICHAEL J MARTIN                ',
#   'total_points': '2.5',
#   'R1_R': 'L',
#   'R1_O': '26',
#   'R2_R': 'L',
#   'R2_O': '20',
#   'R3_R': 'D',
#   'R3_O': '63',
#   'R4_R': 'D',
#   'R4_O': '64',
#   'R5_R': 'W',
#   'R5_O': '58',
#   'R6_R': 'H',
#   'R6_O': None,
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'SHIVAM JHA                      ',
#   'total_points': '2.5',
#   'R1_R': 'L',
#   'R1_O': '29',
#   'R2_R': 'W',
#   'R2_O': '42',
#   'R3_R': 'L',
#   'R3_O': '33',
#   'R4_R': 'W',
#   'R4_O': '46',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '31',
#   'R7_R': 'L',
#   'R7_O': '30'},
#  {'Player_name': 'TEJAS AYYAGARI                  ',
#   'total_points': '2.5',
#   'R1_R': 'L',
#   'R1_O': '27',
#   'R2_R': 'W',
#   'R2_O': '45',
#   'R3_R': 'L',
#   'R3_O': '36',
#   'R4_R': 'W',
#   'R4_O': '57',
#   'R5_R': 'L',
#   'R5_O': '32',
#   'R6_R': 'D',
#   'R6_O': '47',
#   'R7_R': 'L',
#   'R7_O': '33'},
#  {'Player_name': 'ETHAN GUO                       ',
#   'total_points': '2.5',
#   'R1_R': 'W',
#   'R1_O': '30',
#   'R2_R': 'D',
#   'R2_O': '22',
#   'R3_R': 'L',
#   'R3_O': '19',
#   'R4_R': 'D',
#   'R4_O': '48',
#   'R5_R': 'L',
#   'R5_O': '29',
#   'R6_R': 'D',
#   'R6_O': '35',
#   'R7_R': 'L',
#   'R7_O': '34'},
#  {'Player_name': 'JOSE C YBARRA                   ',
#   'total_points': '2.0',
#   'R1_R': 'H',
#   'R1_O': None,
#   'R2_R': 'L',
#   'R2_O': '25',
#   'R3_R': 'H',
#   'R3_O': None,
#   'R4_R': 'L',
#   'R4_O': '44',
#   'R5_R': 'U',
#   'R5_O': None,
#   'R6_R': 'W',
#   'R6_O': '57',
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'LARRY HODGE                     ',
#   'total_points': '2.0',
#   'R1_R': 'L',
#   'R1_O': '14',
#   'R2_R': 'L',
#   'R2_O': '39',
#   'R3_R': 'L',
#   'R3_O': '61',
#   'R4_R': 'B',
#   'R4_O': None,
#   'R5_R': 'L',
#   'R5_O': '15',
#   'R6_R': 'L',
#   'R6_O': '59',
#   'R7_R': 'W',
#   'R7_O': '64'},
#  {'Player_name': 'ALEX KONG                       ',
#   'total_points': '2.0',
#   'R1_R': 'L',
#   'R1_O': '62',
#   'R2_R': 'D',
#   'R2_O': '31',
#   'R3_R': 'L',
#   'R3_O': '10',
#   'R4_R': 'L',
#   'R4_O': '30',
#   'R5_R': 'B',
#   'R5_O': None,
#   'R6_R': 'D',
#   'R6_O': '45',
#   'R7_R': 'L',
#   'R7_O': '43'},
#  {'Player_name': 'MARISA RICCI                    ',
#   'total_points': '2.0',
#   'R1_R': 'H',
#   'R1_O': None,
#   'R2_R': 'L',
#   'R2_O': '11',
#   'R3_R': 'L',
#   'R3_O': '35',
#   'R4_R': 'W',
#   'R4_O': '45',
#   'R5_R': 'H',
#   'R5_O': None,
#   'R6_R': 'L',
#   'R6_O': '40',
#   'R7_R': 'L',
#   'R7_O': '42'},
#  {'Player_name': 'MICHAEL LU                      ',
#   'total_points': '2.0',
#   'R1_R': 'L',
#   'R1_O': '7',
#   'R2_R': 'L',
#   'R2_O': '36',
#   'R3_R': 'W',
#   'R3_O': '42',
#   'R4_R': 'L',
#   'R4_O': '51',
#   'R5_R': 'L',
#   'R5_O': '35',
#   'R6_R': 'L',
#   'R6_O': '53',
#   'R7_R': 'B',
#   'R7_O': None},
#  {'Player_name': 'VIRAJ MOHILE                    ',
#   'total_points': '2.0',
#   'R1_R': 'W',
#   'R1_O': '31',
#   'R2_R': 'L',
#   'R2_O': '2',
#   'R3_R': 'L',
#   'R3_O': '41',
#   'R4_R': 'L',
#   'R4_O': '23',
#   'R5_R': 'L',
#   'R5_O': '49',
#   'R6_R': 'B',
#   'R6_O': None,
#   'R7_R': 'L',
#   'R7_O': '45'},
#  {'Player_name': 'SEAN M MC CORMICK               ',
#   'total_points': '2.0',
#   'R1_R': 'L',
#   'R1_O': '41',
#   'R2_R': 'B',
#   'R2_O': None,
#   'R3_R': 'L',
#   'R3_O': '9',
#   'R4_R': 'L',
#   'R4_O': '40',
#   'R5_R': 'L',
#   'R5_O': '43',
#   'R6_R': 'W',
#   'R6_O': '54',
#   'R7_R': 'L',
#   'R7_O': '44'},
#  {'Player_name': 'JULIA SHEN                      ',
#   'total_points': '1.5',
#   'R1_R': 'L',
#   'R1_O': '33',
#   'R2_R': 'L',
#   'R2_O': '34',
#   'R3_R': 'D',
#   'R3_O': '45',
#   'R4_R': 'D',
#   'R4_O': '42',
#   'R5_R': 'L',
#   'R5_O': '24',
#   'R6_R': 'H',
#   'R6_O': None,
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'JEZZEL FARKAS                   ',
#   'total_points': '1.5',
#   'R1_R': 'L',
#   'R1_O': '32',
#   'R2_R': 'L',
#   'R2_O': '3',
#   'R3_R': 'W',
#   'R3_O': '54',
#   'R4_R': 'L',
#   'R4_O': '47',
#   'R5_R': 'D',
#   'R5_O': '42',
#   'R6_R': 'L',
#   'R6_O': '30',
#   'R7_R': 'L',
#   'R7_O': '37'},
#  {'Player_name': 'ASHWIN BALAJI                   ',
#   'total_points': '1.0',
#   'R1_R': 'W',
#   'R1_O': '55',
#   'R2_R': 'U',
#   'R2_O': None,
#   'R3_R': 'U',
#   'R3_O': None,
#   'R4_R': 'U',
#   'R4_O': None,
#   'R5_R': 'U',
#   'R5_O': None,
#   'R6_R': 'U',
#   'R6_O': None,
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'THOMAS JOSEPH HOSMER            ',
#   'total_points': '1.0',
#   'R1_R': 'L',
#   'R1_O': '2',
#   'R2_R': 'L',
#   'R2_O': '48',
#   'R3_R': 'D',
#   'R3_O': '49',
#   'R4_R': 'L',
#   'R4_O': '43',
#   'R5_R': 'L',
#   'R5_O': '45',
#   'R6_R': 'H',
#   'R6_O': None,
#   'R7_R': 'U',
#   'R7_O': None},
#  {'Player_name': 'BEN LI                          ',
#   'total_points': '1.0',
#   'R1_R': 'L',
#   'R1_O': '22',
#   'R2_R': 'D',
#   'R2_O': '30',
#   'R3_R': 'L',
#   'R3_O': '31',
#   'R4_R': 'D',
#   'R4_O': '49',
#   'R5_R': 'L',
#   'R5_O': '46',
#   'R6_R': 'L',
#   'R6_O': '42',
#   'R7_R': 'L',
#   'R7_O': '54'}]

# %%
#Extracting "state" and "pre_rating" of the second row of each player's data
line2 = re.compile('\s+(?P<state>[A-Z]{2})\s\|\s\d+\s\/\sR\:\s+(?P<pre_rating>\d+)(P\d+)?\s*->\s*\d+(P\d+)?')
line2_result = [m.groupdict() for m in line2.finditer(tournamentinfo[0])]
line2_result
# Out:
# [{'state': 'ON', 'pre_rating': '1794'},
#  {'state': 'MI', 'pre_rating': '1553'},
#  {'state': 'MI', 'pre_rating': '1384'},
#  {'state': 'MI', 'pre_rating': '1716'},
#  {'state': 'MI', 'pre_rating': '1655'},
#  {'state': 'OH', 'pre_rating': '1686'},
#  {'state': 'MI', 'pre_rating': '1649'},
#  {'state': 'MI', 'pre_rating': '1641'},
#  {'state': 'ON', 'pre_rating': '1411'},
#  {'state': 'MI', 'pre_rating': '1365'},
#  {'state': 'MI', 'pre_rating': '1712'},
#  {'state': 'MI', 'pre_rating': '1663'},
#  {'state': 'MI', 'pre_rating': '1666'},
#  {'state': 'MI', 'pre_rating': '1610'},
#  {'state': 'MI', 'pre_rating': '1220'},
#  {'state': 'MI', 'pre_rating': '1604'},
#  {'state': 'MI', 'pre_rating': '1629'},
#  {'state': 'MI', 'pre_rating': '1600'},
#  {'state': 'MI', 'pre_rating': '1564'},
#  {'state': 'MI', 'pre_rating': '1595'},
#  {'state': 'ON', 'pre_rating': '1563'},
#  {'state': 'MI', 'pre_rating': '1555'},
#  {'state': 'ON', 'pre_rating': '1363'},
#  {'state': 'MI', 'pre_rating': '1229'},
#  {'state': 'MI', 'pre_rating': '1745'},
#  {'state': 'ON', 'pre_rating': '1579'},
#  {'state': 'MI', 'pre_rating': '1552'},
#  {'state': 'MI', 'pre_rating': '1507'},
#  {'state': 'MI', 'pre_rating': '1602'},
#  {'state': 'ON', 'pre_rating': '1522'},
#  {'state': 'MI', 'pre_rating': '1494'},
#  {'state': 'ON', 'pre_rating': '1441'},
#  {'state': 'MI', 'pre_rating': '1449'},
#  {'state': 'MI', 'pre_rating': '1399'},
#  {'state': 'MI', 'pre_rating': '1438'},
#  {'state': 'MI', 'pre_rating': '1355'},
#  {'state': 'MI', 'pre_rating': '980'},
#  {'state': 'MI', 'pre_rating': '1423'},
#  {'state': 'MI', 'pre_rating': '1436'},
#  {'state': 'MI', 'pre_rating': '1348'},
#  {'state': 'MI', 'pre_rating': '1403'},
#  {'state': 'MI', 'pre_rating': '1332'},
#  {'state': 'MI', 'pre_rating': '1283'},
#  {'state': 'MI', 'pre_rating': '1199'},
#  {'state': 'MI', 'pre_rating': '1242'},
#  {'state': 'MI', 'pre_rating': '377'},
#  {'state': 'MI', 'pre_rating': '1362'},
#  {'state': 'MI', 'pre_rating': '1382'},
#  {'state': 'MI', 'pre_rating': '1291'},
#  {'state': 'MI', 'pre_rating': '1056'},
#  {'state': 'MI', 'pre_rating': '1011'},
#  {'state': 'MI', 'pre_rating': '935'},
#  {'state': 'MI', 'pre_rating': '1393'},
#  {'state': 'MI', 'pre_rating': '1270'},
#  {'state': 'MI', 'pre_rating': '1186'},
#  {'state': 'MI', 'pre_rating': '1153'},
#  {'state': 'MI', 'pre_rating': '1092'},
#  {'state': 'MI', 'pre_rating': '917'},
#  {'state': 'MI', 'pre_rating': '853'},
#  {'state': 'MI', 'pre_rating': '967'},
#  {'state': 'ON', 'pre_rating': '955'},
#  {'state': 'MI', 'pre_rating': '1530'},
#  {'state': 'MI', 'pre_rating': '1175'},
#  {'state': 'MI', 'pre_rating': '1163'}]

# %%
#Converting the two data sets to DataFrame format and merging there into a DataFrame
tournament_line1 = pd.DataFrame(line1_result)
tournament_line2 = pd.DataFrame(line2_result)
tournament = pd.concat([tournament_line1, tournament_line2], axis = 1)
tournament.head()
# Out:
#                         Player_name total_points R1_R R1_O R2_R R2_O R3_R  \
# 0  GARY HUA                                  6.0    W   39    W   21    W
# 1  DAKSHESH DARURI                           6.0    W   63    W   58    L
# 2  ADITYA BAJAJ                              6.0    L    8    W   61    W
# 3  PATRICK H SCHILLING                       5.5    W   23    D   28    W
# 4  HANSHI ZUO                                5.5    W   45    W   37    D
#
#   R3_O R4_R R4_O R5_R R5_O R6_R R6_O R7_R R7_O state pre_rating
# 0   18    W   14    W    7    D   12    D    4    ON       1794
# 1    4    W   17    W   16    W   20    W    7    MI       1553
# 2   25    W   21    W   11    W   13    W   12    MI       1384
# 3    2    W   26    D    5    W   19    D    1    MI       1716
# 4   12    D   13    D    4    W   14    W   17    MI       1655

# %%
# Calculate the average of the opponents' pre-ratings
round_opponent_column_index = [3,5,7,9,11,13,15] # opponent number in row
for i in range(tournament.shape[0]): # return the len of tournament
    sum_pre_opponents_rating = 0
    count = 0 
    for p in round_opponent_column_index: # find every opponents' rating
        if (tournament.iloc[i,p] != None): # judge non-empty opponents
            sum_pre_opponents_rating += int(tournament.iloc[int(tournament.iloc[i,p])-1,17]) # accumulation of opponent rating values
            count += 1 # store the totle number of opponents
    pre_ave_opponents_rating = int(sum_pre_opponents_rating / count)
    playerinfo.at[i,'Average Pre Tournament Chess Rating of Opponents'] = pre_ave_opponents_rating

playerinfo.head()
# Out:
#                   Name State Total Number of Points Pre-Rating  \
# 0             GARY HUA    ON                    6.0       1794
# 1      DAKSHESH DARURI    MI                    6.0       1553
# 2         ADITYA BAJAJ    MI                    6.0       1384
# 3  PATRICK H SCHILLING    MI                    5.5       1716
# 4           HANSHI ZUO    MI                    5.5       1655
#
#    Average Pre Tournament Chess Rating of Opponents
# 0                                            1605.0
# 1                                            1469.0
# 2                                            1563.0
# 3                                            1573.0
# 4                                            1500.0

# %% [markdown]
# ## Converting dataframe to a .csv file

# %%
playerinfo.to_csv("tournament_playerinfo.csv", sep='\t', encoding='utf-8') #Use comma separator and utf-8 encoding format
